# %% [markdown]
# <font color=darkred>
#
# # Soc220: Computational Text Analysis
# ## Lab4 (Week 5): Text preprocessing and cleaning
#
# <br>
#
# <img src="mickey.jpg" alt="Drawing" style="width: 900px;"/>
#
# ***
#     2/21/18

# %% [markdown]
# ***
#
# ## Today:
#
# Like Mickey as sorcerer's apprentice, we're going to automate cleaning texts, and while necessary, we can also end up with useless stuff everywhere.
#
# Denny and Spirling (Forthcoming): preprocessing should (1) reduce computational complexity, (2) reduce noise, and (3) allow for better human interptability.
#
# As a consequence of 7 different preprocessing decisions, they suggest $2^7 = 128$ possible configurations of a given corpus. Think: probability space over the various models (plus some error), but also space over possible configurations.
#
# So, what to do?
#
# Follow the steps they suggest and check in each time to see how a simple word frequency count changes. Along the way: Pandas and simple visualizations.
#
# Then, following Grimmer and Stewart (2013), we're going to bag-o-words as the ''standard'' recipe.
#
# Lastly, we'll discuss using a tokenizer to do exploration.
#
# **
# <em>
# Denny and Spirling:**
#
# 0.) Basic cleaning (removing artifacts of code/scrape, encoding?, maybe spell check?) <br>
# 1.) Punctuation removal <br>
# 2.) Numbers removal (or transformation into text) <br>
# 3.) Lowecase <br>
# 4.) Stemming (/lemmatizing) words <br>
# 5.) Stop-words removal <br>
# 6.) N-gram size <br>
# 7.) Infrequent term removal

# %%
#!pip install -U nltk

# %%
#!pip install -U spacy

# %%
#!python -m spacy download en

# %%
#!pip install -U gensim

# %%
#nltk.download()

# %% [markdown]
# <font color=darkred>
#
# ### Great code for getting around Harvard login. (Thanks Ariella!)
#
#
# Great for getting databases:
#
# http://e-research.lib.harvard.edu/V?func=find-db-1

# %% [raw]
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support import expected_conditions as EC
# from selenium.webdriver.support.ui import WebDriverWait
# from selenium.common.exceptions import NoSuchElementException
# from selenium.webdriver.support.select import Select
#
#
# driver.get('https://course-evaluation-reports.fas.harvard.edu/fas/course_summary.html?course_id=' + str(i))
# if driver.title == 'HarvardKey Login':
#     user = driver.find_element_by_name('username')
#     user.send_keys(username)
#     pw = driver.find_element_by_name('password')
#     pw.send_keys(password)
#     pw.send_keys(Keys.RETURN)

# %% [markdown]
# ### To do list:
#
# 1. ML to fix OCR.
# 2. Bulk extracting PDFs for OCRing.

# %% [markdown]
# <font color=darkgreen>
#
#
# ### 0. Loading and wrangling some data from a pickle object
#
# Data: Verbatim accounts of (UK) House of Commons debates for the period 1660-1739
#
# Why you should care:
#
# 1. 1642, English Civil War starts -- republican government experiment.
# 1. 1649, King Charles I decapitated.
# 1. 1660, Restoration: Charles' brother takes over as Charles II.
# 2. 1660, the corpose of Oliver Cromwell is put on trial (found guilty), and he is re-hung and depicated.
# 3. 1672, King declares bankruptcy.
# 5. 1688, another coup, this time James I is dethroned.
# 6. 1689, constitutional monarchy established.
# 7. 1694, Bank of England financies the state.
# 8. 1697, East India Company is re-started
# 7. 1707, unity of Scotland and England creats Great Britain
# 8. 1714, beginning of 'Whig Supremacy.'
# 9. 1722, South Sea Bubble.
# 10. 1730s, Coffee-houses of English financial capitalism in Exchange Alley, the site of where modern London Stock Exchanges.

# %% [markdown]
# ## AKA YOUR DATA GOES HERE

# %%
import pickle

#n.b. 'read binary'
session_texts = pickle.load(open("session_singular_texts.p", "rb" ))
session_titles = pickle.load(open("sessions_titles.p", "rb" ))

# %%
len(session_texts)
# Out:
# 198

# %%
len(session_titles)
# Out:
# 198

# %%
session_titles[20:35]
# Out:
# ['The second parliament of Charles II: Seventeenth session - begins 23/5/1678',
#  'The second parliament of Charles II: Eighteenth session - begins 21/10/1678',
#  'The third Parliament of Charles II: First session - begins 6/3/1679',
#  'The fourth Parliament of Charles II: First session (1 of 5) - begins 17/10/1679',
#  'The fourth Parliament of Charles II: First session (2 of 5)- begins 4/11/1680',
#  'The fourth Parliament of Charles II: First session (3 of 5) - begins 12/11/1680',
#  'The fourth Parliament of Charles II: First session (4 of 5) - begins 21/10/1680',
#  'The fourth Parliament of Charles II: First session (5 of 5) - begins 23/12/1680',
#  'The Oxford Parliament: - begins 21/3/1681',
#  "King James' Parliament: The first convention - begins 19/5/1685",
#  "King James' Parliament: The second convention - begins 22/1/1689",
#  "King James' Parliament: The succession of William and Mary - begins 13/2/1689",
#  'The Convention Parliament (William): The convention becomes a Parliament - begins 20/2/1689',
#  'The Convention Parliament (William): First session (2 of 2) - begins 1/5/1689',
#  'The Convention Parliament (William): Second session - begins 23/10/1689']

# %%
example_title = session_titles[25]
session_titles[25]
# Out:
# 'The fourth Parliament of Charles II: First session (3 of 5) - begins 12/11/1680'

# %%
import re

# %%
re.findall(r"/[\d]+", example_title)
# Out:
# ['/11', '/1680']

# %%
re.findall(r"/[\d]+", example_title)[0].strip('/')
# Out:
# '11'

# %%
re.findall(r"/[\d]+", example_title)[1].strip('/')
# Out:
# '1680'

# %% [markdown]
# ### Getting the names of monarchs

# %%
import nltk
#from nltk import word_tokenize, pos_tag, ne_chunk

tokens = nltk.wordpunct_tokenize(example_title)
nltk.ne_chunk(nltk.pos_tag(tokens))
# Out:
# Tree('S', [('The', 'DT'), ('fourth', 'JJ'), Tree('ORGANIZATION', [('Parliament', 'NNP')]), ('of', 'IN'), Tree('PERSON', [('Charles', 'NNP'), ('II', 'NNP')]), (':', ':'), ('First', 'JJ'), ('session', 'NN'), ('(', '('), ('3', 'CD'), ('of', 'IN'), ('5', 'CD'), (')', ')'), ('-', ':'), ('begins', 'VBZ'), ('12', 'CD'), ('/', 'JJ'), ('11', 'CD'), ('/', 'NN'), ('1680', 'CD')])

# %%
nltk.pos_tag(tokens)
# Out:
# [('The', 'DT'),
#  ('fourth', 'JJ'),
#  ('Parliament', 'NNP'),
#  ('of', 'IN'),
#  ('Charles', 'NNP'),
#  ('II', 'NNP'),
#  (':', ':'),
#  ('First', 'JJ'),
#  ('session', 'NN'),
#  ('(', '('),
#  ('3', 'CD'),
#  ('of', 'IN'),
#  ('5', 'CD'),
#  (')', ')'),
#  ('-', ':'),
#  ('begins', 'VBZ'),
#  ('12', 'CD'),
#  ('/', 'JJ'),
#  ('11', 'CD'),
#  ('/', 'NN'),
#  ('1680', 'CD')]

# %%
import spacy
spacy = spacy.load('en',tagger=False,parser=False,matcher=False)

spacy_example_title = spacy(example_title)
for token in spacy_example_title:
    print(token.text,'--->',token.pos_)
# Out:
# The ---> DET
# fourth ---> ADJ
# Parliament ---> PROPN
# of ---> ADP
# Charles ---> PROPN
# II ---> PROPN
# : ---> PUNCT
# First ---> ADJ
# session ---> NOUN
# ( ---> PUNCT
# 3 ---> NUM
# of ---> ADP
# 5 ---> NUM
# ) ---> PUNCT
# - ---> PUNCT
# begins ---> VERB
# 12/11/1680 ---> NUM

# %%
for entity in spacy_example_title.ents:
    print(entity.text, entity.label_)
# Out:
# fourth ORDINAL
# Parliament of Charles II ORG
# First ORDINAL
# 3 CARDINAL
# 5 CARDINAL
# 12/11/1680 DATE

# %%
[token.text for token in spacy(example_title) if token.pos_ == 'PROPN']
# Out:
# ['Parliament', 'Charles', 'II']

# %%
[entity.text for entity in spacy(example_title).ents if entity.label_ == 'PERSON']
# Out:
# []

# %%
#suffix
re.findall(r"(?:[A-Z][A-Z'\-_]+)",example_title)
# Out:
# ['II']

# %%
monarchs_list = []
dates_list = []
proceedings_text_list = []

for title, text in zip(session_titles, session_texts):
    
    try:
        month = re.findall(r"/[\d]+", title)[0].strip('/')
        #print(month)
        
        year = re.findall(r"/[\d]+", title)[1].strip('/')
        #print(year)
        
        date = year+'_'+month
        print(date)
        
        monarch = [token.text for token in spacy(title) if token.tag_ == 'NNP']
        print('\t',monarch)
        
        print('\t\t',str(text[1000:1050]))
        
        monarchs_list.append(monarch)
        dates_list.append(date)
        proceedings_text_list.append(str(text))
        
        
    except IndexError:
        print('passed')
# Out:
# passed
# 1660_4
# 	 ['Convention', 'Parliament']
# 		 ess, and Security of the Kingdom.", "'We do assure
# 1660_11
# 	 ['Convention', 'Parliament']
# 		 easons, he had determined to\ndissolve them in the
# 1661_5
# 	 ['Charles', 'II']
# 		 the Year, and all that has been done since we part
# 1661_11
# 	 ['Charles', 'II']
# 		 hat extraordinary:\nIt is to say something to you
# 1663_2
# 	 ['Charles', 'II']
# 		 shall have\nexamin'd well the grounds, I doubt not
# 1664_3
# 	 ['Charles', 'II']
# 		 ept without a Parliament. I pray watch these Whisp
# 1664_11
# 	 ['Charles', 'II']
# 		  hath been deferred thus\nlong: You have had leisu
# 1665_10
# 	 ['Charles', 'II', 'Oxford']
# 		 'The truth is, as I enter'd upon this War by your\
# 1666_9
# 	 ['Charles', 'II']
# 		 n; and I can tell you truly, I desire to put you t
# 1667_7
# 	 ['Charles', 'II']
# 		  of this Month; and that the\nHouse should be adjo
# 1667_10
# 	 ['Charles', 'II']
# 		 you.'", "Hereupon the new Lord-Keeper Bridgeman ma
# 1669_10
# 	 ['Charles', 'II']
# 		  to the Navy, and that extraordinary\nFleet for wh
# 1670_2
# 	 ['Charles', 'II']
# 		 ngdom's Interest as well as\nmine; and the ill Con
# 1673_2
# 	 ['Charles', 'II']
# 		 ipture, the King may upon this Occasion say,\nHe t
# 1673_10
# 	 ['Charles', 'II']
# 		  for the War, and\nCondescensions at the Treaty, g
# 1674_1
# 	 ['Charles', 'II']
# 		 ll reasonably propose, but\nI shall be ready to re
# 1675_4
# 	 ['Charles', 'II']
# 		 ivances;\nof which this is not the least, That the
# 1675_10
# 	 ['Charles', 'II']
# 		  desire you wou'd\ndefer those Debates, till you h
# 1677_2
# 	 ['Charles', 'II']
# 		 For I declare myself very plainly\nto you, that I
# 1678_5
# 	 ['Charles', 'II']
# 		 \nanother Part of it is cut off by a Clause in the
# 1678_10
# 	 ['Charles', 'II']
# 		 sed for their disbanding to have been\nill-employe
# 1679_3
# 	 ['Parliament', 'Charles', 'II']
# 		 ded as much of the Army as I could get Money\nto d
# 1679_10
# 	 ['Parliament', 'Charles', 'II']
# 		  he thought fit to appoint a\nDay for their meetin
# 1680_11
# 	 ['Parliament', 'Charles', 'II']
# 		 e, when you\nhave old Laws in being, that have app
# 1680_11
# 	 ['Parliament', 'Charles', 'II']
# 		 zens of London having before delivered in a Petiti
# 1680_10
# 	 ['Parliament', 'Charles', 'II']
# 		 l by the\nOaths of self-acknowledg'd Partners in t
# 1680_12
# 	 ['Parliament', 'Charles', 'II']
# 		 reason, and in that Case are always condemned to b
# 1681_3
# 	 ['Oxford', 'Parliament']
# 		 w'd\nto the last Parliament; how I recommended not
# 1685_5
# 	 ['King', 'James', 'Parliament']
# 		 jesty, to acquaint You, that there are divers Prel
# 1689_1
# 	 ['King', 'James', 'Parliament']
# 		 on only as Formalities: But I am so\nsensible of m
# 1689_2
# 	 ['King', 'James', 'Parliament', 'William', 'Mary']
# 		 thout Consent of\nParliament: By committing and pr
# 1689_2
# 	 ['Convention', 'Parliament', 'William', 'Parliament']
# 		 King James was sail'd with French\nTroops from Bre
# 1689_5
# 	 ['Convention', 'Parliament', 'William']
# 		 id Prideaux\nseveral times desir'd to be heard bef
# 1689_10
# 	 ['Convention', 'Parliament', 'William']
# 		 o the House, from the Journals of the\nlast Sessio
# 1690_3
# 	 ['King', 'William']
# 		 o this, I desire you will forthwith make a Settlem
# 1690_10
# 	 ['King', 'William']
# 		 ingness, as could not proceed but from\nan affecti
# 1691_10
# 	 ['King', 'William']
# 		 all. And as I do not doubt, but you will take\ncar
# 1692_11
# 	 ['King', 'William']
# 		 ligence, and do design to augment their Land-Force
# 1693_11
# 	 ['King', 'William']
# 		 future. And it will well deserve your\nConsiderati
# 1694_11
# 	 ['King', 'William']
# 		  that I cannot\ndoubt of your Assistance at this T
# 1695_11
# 	 ['King', 'William']
# 		  by the Advice of my\nfirst Parliament; who though
# 1696_10
# 	 ['King', 'William']
# 		 atal to us: But as they\nhave failed in those Expe
# 1697_12
# 	 ['King', 'William']
# 		 main considerable Deficiencies to be provided for.
# 1698_8
# 	 ['King', 'William']
# 		 ion.", "'The one is, what Strength ought to be mai
# 1699_11
# 	 ['King', 'William']
# 		 is concerned, and\nwherein the Honour of the Kingd
# 1701_2
# 	 ['King', 'William']
# 		 stant Line, after me and the Princess.\nThe Happin
# 1701_12
# 	 []
# 		 he loyal and seasonable Addresses of my People.',
# 1699_1
# 	 ['Sir', 'Charles', 'Sedley']
# 		 n Pay, disciplin'd Troops; that all our Neighbours
# 1702_5
# 	 ['Queen', 'Anne', 'Begins']
# 		 ourages me in this great Undertaking, which, I pro
# 1702_10
# 	 ['Queen', 'Anne']
# 		  of the whole Confederacy.", "'I have met with so
# 1702_10
# 	 ['Queen', 'Anne', 'Act']
# 		 ss,\nwhereas (fn. 5)\n(fn. 6) the Laws do provide
# 1702_12
# 	 ['Queen', 'Anne']
# 		 , in pursuance of\nthose Acts, should receive the
# 1703_11
# 	 ['Queen', 'Anne']
# 		 h\nwhich you supported me in this War, and the Ass
# 1704_4
# 	 ['Queen', 'Anne', 'Ashby', 'White']
# 		 by in the Country, but Judgment was given against
# 1704_2
# 	 ['Queen', 'Anne']
# 		 d to have been made by Sir John\nPackington, in th
# 1704_10
# 	 ['Queen', 'Anne']
# 		 nof all my Subjects.", "'Gentlemen of the House of
# 1705_10
# 	 ['Queen', 'Anne']
# 		 urable John Smith Esq;\nand William Bromley, Esq;
# 1706_4
# 	 ['Queen', 'Anne', 'Act', 'Union']
# 		 ord\nPresident, Lord Privy-Seal, Duke of Somerset,
# passed
# 1706_12
# 	 ['Parliament', 'Queen', 'Anne']
# 		 asure of one Prince to disturb the Repose, and end
# 1707_4
# 	 ['Parliament', 'Queen', 'Anne']
# 		 s, Rosin, &c. of the Growth\nand Product of France
# 1707_11
# 	 ['First', 'Parliament', 'Great', 'Britain']
# 		 te this just and necessary War, till we obtain a s
# 1708_11
# 	 ['Second', 'Parliament', 'Great', 'Britain']
# 		 ion, as any body.' But when he\nhad had his Jest,
# 1709_11
# 	 ['Second', 'Parliament', 'Great', 'Britain']
# 		 heir Infincerity. The Operations of the War were n
# 1710_11
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		 utely\nnecessary for our common Safety.", "'The ca
# 1711_12
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		 estant Religion, and\nthe Laws and Liberties of th
# 1711_2
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		 he Year\n1711, for the General-Officers, Contingen
# 1712_3
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		 olv'd, 'That the Duty upon all other Paper, not\np
# 1713_4
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		  Opportunity to adjust their several Interests, th
# 1713_4
# 	 ['Third', 'Parliament', 'Great', 'Britain']
# 		 od\n(for the Services of the Navy) the like Sum, g
# 1714_2
# 	 ['Fourth', 'Parliament', 'Great', 'Britain']
# 		 n Great Britain and France, should be offered to t
# 1714_4
# 	 ['Fourth', 'Parliament', 'Great', 'Britain']
# 		 ence to an Order of the\nlate House of Commons, to
# 1714_4
# 	 ['Fourth', 'Parliament', 'Great', 'Britain']
# 		 e been made from\nTime to Time, by the Engineers a
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# 1714_8
# 	 ['Parliament', 'Great', 'Britain', 'George']
# 		 last motion was agreed to. This and\nthe three fol
# 1715_3
# 	 ['First', 'Parliament', 'George', 'I']
# 		 2) Lord Finch,\nhe was elected Nem. Con.", "On the
# 1715_10
# 	 ['First', 'Parliament', 'George', 'I']
# 		 in the Room\nof Sir Richard Onslow, Bart. who had
# 1716_4
# 	 ['First', 'Parliament', 'George', 'I']
# 		 m\nto direct the Commons in a Matter which concern
# 1717_2
# 	 ['First', 'Parliament', 'George', 'I']
# 		 the happy Consequences of which have already very
# 1717_11
# 	 ['First', 'Parliament', 'George', 'I']
# 		 to my good\nSubjects, nor an Encouragement to our
# 1718_11
# 	 ['First', 'Parliament', 'George', 'I']
# 		 h some were not at all,\nand others not so fully,
# 1719_11
# 	 ['First', 'Parliament', 'George']
# 		  War by the Influence of British\nArms and Counsel
# 1720_12
# 	 ['First', 'Parliament', 'George', 'I']
# 		 e unhappy Turn of Affairs, which\nhas so much affe
# 1721_10
# 	 ['First', 'Parliament', 'George']
# 		 \nwanting to ourselves, if we neglected to improve
# 1722_10
# 	 ['Second', 'Parliament', 'George', 'I']
# 		 pplause, in\nthe last Parliament. This Motion was
# 1724_1
# 	 ['Second', 'Parliament', 'George', 'I']
# 		 ate and wicked Practices. The Augmentation,\nwhich
# 1724_11
# 	 ['Second', 'Parliament', 'George', 'I']
# 		  by Sea and Land, for the Defence\nand Safety of t
# 1726_1
# 	 ['Second', 'Parliament', 'George', 'I']
# 		 to have\nlaid the Foundation of new Troubles and D
# 1727_1
# 	 ['Second', 'Parliament', 'George']
# 		 ble and darling Interests and Privileges of this\n
# passed
# passed
# 1727_6
# 	 ['Sixth', 'Parliament', 'Great', 'Britain', 'King', 'George', 'II']
# 		  Crown of this Realm in Succession.'\nThe Parliame
# 1728_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 .", 'My Lords and Gentlemen,', '"It is a great Sat
# 1729_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 ell under\nConsideration, in settling and reconcil
# 1730_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 the Foundation, and is\nagreeable to the Purport a
# 1731_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 s; and no Endeavours have been wanting, conformabl
# 1732_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 of concluding\nthe Quadruple Alliance, the several
# 1732_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 on this Occasion, he moved, 'That the Bill\nmight
# 1732_2
# 	 ['First', 'Parliament', 'George', 'II']
# 		 enever he\nis necessarily obliged to desire Assist
# 1732_2
# 	 ['First', 'Parliament', 'George', 'II']
# 		 also the 17th, 18th, and 23d, during which\nTime a
# 1733_1
# 	 ['First', 'Parliament', 'George', 'II']
# 		 u will, with the same Chearfulness as I have alway
# 1733_2
# 	 ['First', 'Parliament', 'George', 'II']
# 		  directly into Ireland from any of our Colonies\ni
# 1733_2
# 	 ['First', 'Parliament', 'George', 'II']
# 		  do, would get up\nand six a Day when he thinks it
# 1733_3
# 	 ['First', 'Parliament', 'George', 'II']
# 		  Ends proposed by this\nScheme is, the preventing
# 1733_4
# 	 ['First', 'Parliament', 'George', 'II']
# 		 n they lent their Money to the Publick; and from\n
# passed
# 1734_1
# 	 ['Parliament', 'George', 'II']
# 		 egardless of the present\nEvents, or be unconcerne
# 1734_1
# 	 ['Parliament', 'George', 'II']
# 		 , be laid before the House.", "'It is very well kn
# 1734_2
# 	 ['Parliament', 'George', 'II']
# 		 are most burthensome and grievous, their Houses be
# 1734_2
# 	 ['Parliament', 'George', 'II']
# 		 ese\nEstimates Gentlemen will find, that the Charg
# 1734_2
# 	 ['Parliament', 'George', 'II']
# 		 d the precarious State in which\nthe Affairs of Eu
# 1734_2
# 	 ['Parliament', 'George', 'II']
# 		 just: For as to the Electors, the People of\nGreat
# 1734_3
# 	 ['Parliament', 'George', 'II']
# 		 on better able to support it than myself: But I\nh
# 1734_3
# 	 ['Parliament', 'George', 'II']
# 		 curing an Accommodation, may in due time\nhave the
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# passed
# 1721_6
# 	 ['George', 'I', 'King', 'Spain', 'Gibraltar']
# 		 my Parliament. And to\ngive your Majesty a farther
# passed
# passed
# passed
# passed
# passed
# 1733_4
# 	 []
#
# passed
# passed
# passed
# passed
# 1735_1
# 	 ['Parliament', 'George', 'II']
# 		 , or being carried on, are so obvious,\nthat I am
# 1735_2
# 	 ['Parliament', 'George', 'II']
# 		 r: Nor can it be\nexpected that his Majesty should
# 1735_2
# 	 ['Parliament', 'George', 'II']
# 		 tion\nmade to the Land-Service; and in a third the
# 1735_2
# 	 ['Parliament', 'George', 'II']
# 		 to appointing a Committee to inspect the Estimate
# passed
# 1736_1
# 	 ['Parliament', 'George', 'II']
# 		 l, from an absolute Necessity of preserving that B
# 1736_1
# 	 ['Parliament', 'George', 'II']
# 		  Majesty's Royal Person and Government, and\nwith
# 1736_3
# 	 ['Parliament', 'George', 'II']
# 		 eir Successors that the\nsaid Hundred or Wapontake
# 1736_4
# 	 ['Parliament', 'George', 'II']
# 		 e was read accordingly. By a Clause in the Bill, e
# passed
# 1737_2
# 	 ['Parliament', 'George', 'II']
# 		 e Throne and the Woolsacks, spoke as follows:", 'M
# 1737_2
# 	 ['Parliament', 'George', 'II']
# 		 y's first and chief Council, there can be no\nQues
# 1737_3
# 	 ['Parliament', 'George', 'II']
# 		 Occasion took Notice of\nthe great Charge that Hos
# 1737_3
# 	 ['Parliament', 'George', 'II']
# 		 ir exclusive Privilege. I confess, Sir, this Argum
# 1737_3
# 	 ['Parliament', 'George', 'II']
# 		 ittee did not come to any Resolution that Day;\nth
# 1737_3
# 	 ['Parliament', 'George', 'II']
# 		  per Cent. it is not, in my Opinion,\nto be questi
# 1737_5
# 	 ['Parliament', 'George', 'II']
# 		 of Peers for every Offence committed, or supposed
# passed
# passed
# passed
# passed
# 1738_1
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 Service of the\ncurrent Year to be laid before you
# 1738_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 "'Sir,", "'It is very extraordinary, that a Resolu
# 1738_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 ep a few regular Troops in Pay for one\nYear, in c
# 1738_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 ring the same, under the Direction of the Chancell
# 1738_3
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 eatly interrupted by the continual Depredations of
# 1738_3
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 nisters, to him in\nanswer to Letters wrote by one
# 1738_3
# 	 ['Second', 'Parliament', 'George', 'II']
# 		  Barbarity, and Injustice, which we have heard pro
# 1738_4
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 , 'The next Debate we shall give an Account of, is
# 1738_5
# 	 ['Second', 'Parliament', 'George', 'II']
# 		  that Hour\nGentlemen are all present in the House
# 1739_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 t Power, in vindicating and protecting\nour undoub
# 1739_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 in Europe and America, which\nhave not already bee
# 1739_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		  persuade People, that there is no Difference\nbet
# 1739_2
# 	 ['Second', 'Parliament', 'George', 'II']
# 		 earching for Goods, which they\ndeemed contraband,
# passed

# %%
len(monarchs_list)
# Out:
# 139

# %%
len(dates_list)
# Out:
# 139

# %%
len(proceedings_text_list)
# Out:
# 139

# %% [markdown]
# ## Data structure choices

# %%
# 'Charles II' * [:28] 
# 'James' * 3 [28:31]
# 'Convention' [:3]; [32:34]
# 'William and Mary' [34:46]
# 'Anne' [49:73]
# 'George I' [74:88]
# 'George II' [88:109]

monarchs = ['charles2','james','convention','william_mary','anne','george1','george2']
proceedings = [
    " ".join(proceedings_text_list[:28]),
    " ".join(proceedings_text_list[28:31]),
    " ".join(proceedings_text_list[:3]).join(proceedings_text_list[32:34]),
    " ".join(proceedings_text_list[34:46]),
    " ".join(proceedings_text_list[49:73]),
    " ".join(proceedings_text_list[74:88]),
    " ".join(proceedings_text_list[88:109])
]

# %% [markdown]
# ### By Monarch

# %%
import pandas as pd

df_monarch = pd.DataFrame({
    'monarch':monarchs,
    'proceedings':proceedings
})
df_monarch
# Out:
#         monarch                                        proceedings
# 0      charles2  ['Pages 2-25', 'The History and Proceedings of...
# 1         james  ['Pages 164-199', 'The History and Proceedings...
# 2    convention  ['Pages 309-355', 'The History and Proceedings...
# 3  william_mary  ['Pages 373-384', 'The History and Proceedings...
# 4          anne  ['Pages 203-211', 'The History and Proceedings...
# 5       george1  ['Pages 47-68', 'The History and Proceedings o...
# 6       george2  ['Pages 15-31', 'The History and Proceedings o...

# %% [markdown]
# ### By date

# %%
df_date = pd.DataFrame({
    'date':dates_list,
    'proceedings':proceedings_text_list
})
df_date.head()
# Out:
#       date                                        proceedings
# 0   1660_4  ['Pages 2-25', 'The History and Proceedings of...
# 1  1660_11  ['Pages 25-31', 'The History and Proceedings o...
# 2   1661_5  ['Pages 31-46', 'The History and Proceedings o...
# 3  1661_11  ['Pages 46-60', 'The History and Proceedings o...
# 4   1663_2  ['Pages 60-72', 'The History and Proceedings o...

# %% [markdown]
# <font color=darkred>
#
# ### Cleaning with a toy bit of text

# %%
#select just a bit of text to see what happens.
toy_text = proceedings_text_list[5][1000:1600]

# %%
toy_text
# Out:
# 'ept without a Parliament. I pray watch these Whisperers all you can, as\\nMen who use their utmost endeavours to sow Jealousies\\nbetween You and Me; and I do promise you they shall\\nnot prevail with me; and I do promise myself, they shall\\nnot prevail with you: And the truth is, we are both concern\'d they shou\'d not; and we shall then, with God\'s\\nBlessing, prevent all the mischief they intend.", "\'You may judge by the late Treason in the North, for\\nwhich so many Men have been executed, how active the\\nSpirits of many of our old Enemies still are, notwithstanding all our Mercy. I do assure you'

# %% [markdown]
# <font color=darkgreen>
#
# ### 0. Basic cleaning: spell check(optional), removing artifacts from scrape, encoding characters.

# %%
toy_text.replace('\\n', ' ').replace('\\r', '').replace('\\t', '').replace("\\","").replace("-",'')
# Out:
# 'ept without a Parliament. I pray watch these Whisperers all you can, as Men who use their utmost endeavours to sow Jealousies between You and Me; and I do promise you they shall not prevail with me; and I do promise myself, they shall not prevail with you: And the truth is, we are both concern\'d they shou\'d not; and we shall then, with God\'s Blessing, prevent all the mischief they intend.", "\'You may judge by the late Treason in the North, for which so many Men have been executed, how active the Spirits of many of our old Enemies still are, notwithstanding all our Mercy. I do assure you'

# %%
#nltk.clean_html(unescape(test_string.decode('utf8')))

# %%
def step0(text):
    corrected_text = toy_text.replace('\\n', ' ').replace('\r', '').replace('\t', '').replace("\\","").replace("-",'')
    #corrected_text = corrected_text.replace('The History and Proceedings of the House of Commons: Volume 1, \\
    #1660-1680. Originally published by Chandler, London, 1742.', '')
    
    #DONT COPY THIS PART OF TEXT
    #corrected_text = corrected_text[220:] #removes junk text from start of each page
    #corrected_text = corrected_text[:-50] #removes junk at very end of each proceeding
    return corrected_text

# %%
step0(toy_text)
# Out:
# 'ept without a Parliament. I pray watch these Whisperers all you can, as Men who use their utmost endeavours to sow Jealousies between You and Me; and I do promise you they shall not prevail with me; and I do promise myself, they shall not prevail with you: And the truth is, we are both concern\'d they shou\'d not; and we shall then, with God\'s Blessing, prevent all the mischief they intend.", "\'You may judge by the late Treason in the North, for which so many Men have been executed, how active the Spirits of many of our old Enemies still are, notwithstanding all our Mercy. I do assure you'

# %%
toy_text = step0(toy_text)

# %%
toy_text
# Out:
# 'ept without a Parliament. I pray watch these Whisperers all you can, as Men who use their utmost endeavours to sow Jealousies between You and Me; and I do promise you they shall not prevail with me; and I do promise myself, they shall not prevail with you: And the truth is, we are both concern\'d they shou\'d not; and we shall then, with God\'s Blessing, prevent all the mischief they intend.", "\'You may judge by the late Treason in the North, for which so many Men have been executed, how active the Spirits of many of our old Enemies still are, notwithstanding all our Mercy. I do assure you'

# %% [markdown]
# <font color=darkgreen>
#
# ### 1. Punctuation removal
#
# #### punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

# %%
re.sub('[^A-Za-z0-9]+', ' ', str(toy_text))
# Out:
# 'ept without a Parliament I pray watch these Whisperers all you can as Men who use their utmost endeavours to sow Jealousies between You and Me and I do promise you they shall not prevail with me and I do promise myself they shall not prevail with you And the truth is we are both concern d they shou d not and we shall then with God s Blessing prevent all the mischief they intend You may judge by the late Treason in the North for which so many Men have been executed how active the Spirits of many of our old Enemies still are notwithstanding all our Mercy I do assure you'

# %%
def step1(text):
    corrected_text = re.sub('[^A-Za-z0-9]+', ' ', str(text))
    corrected_text = corrected_text.split(' ') #split on white space into a list
    return corrected_text

# %%
toy_text = step1(toy_text)

# %%
toy_text
# Out:
# ['ept',
#  'without',
#  'a',
#  'Parliament',
#  'I',
#  'pray',
#  'watch',
#  'these',
#  'Whisperers',
#  'all',
#  'you',
#  'can',
#  'as',
#  'Men',
#  'who',
#  'use',
#  'their',
#  'utmost',
#  'endeavours',
#  'to',
#  'sow',
#  'Jealousies',
#  'between',
#  'You',
#  'and',
#  'Me',
#  'and',
#  'I',
#  'do',
#  'promise',
#  'you',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'me',
#  'and',
#  'I',
#  'do',
#  'promise',
#  'myself',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'you',
#  'And',
#  'the',
#  'truth',
#  'is',
#  'we',
#  'are',
#  'both',
#  'concern',
#  'd',
#  'they',
#  'shou',
#  'd',
#  'not',
#  'and',
#  'we',
#  'shall',
#  'then',
#  'with',
#  'God',
#  's',
#  'Blessing',
#  'prevent',
#  'all',
#  'the',
#  'mischief',
#  'they',
#  'intend',
#  'You',
#  'may',
#  'judge',
#  'by',
#  'the',
#  'late',
#  'Treason',
#  'in',
#  'the',
#  'North',
#  'for',
#  'which',
#  'so',
#  'many',
#  'Men',
#  'have',
#  'been',
#  'executed',
#  'how',
#  'active',
#  'the',
#  'Spirits',
#  'of',
#  'many',
#  'of',
#  'our',
#  'old',
#  'Enemies',
#  'still',
#  'are',
#  'notwithstanding',
#  'all',
#  'our',
#  'Mercy',
#  'I',
#  'do',
#  'assure',
#  'you']

# %% [markdown]
# <font color=darkgreen>
#
# ### 2. Numbers removal

# %%
#We are now in list land so each command has to be done to a list of words
[word for word in toy_text if word.isalpha()]
# Out:
# ['ept',
#  'without',
#  'a',
#  'Parliament',
#  'I',
#  'pray',
#  'watch',
#  'these',
#  'Whisperers',
#  'all',
#  'you',
#  'can',
#  'as',
#  'Men',
#  'who',
#  'use',
#  'their',
#  'utmost',
#  'endeavours',
#  'to',
#  'sow',
#  'Jealousies',
#  'between',
#  'You',
#  'and',
#  'Me',
#  'and',
#  'I',
#  'do',
#  'promise',
#  'you',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'me',
#  'and',
#  'I',
#  'do',
#  'promise',
#  'myself',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'you',
#  'And',
#  'the',
#  'truth',
#  'is',
#  'we',
#  'are',
#  'both',
#  'concern',
#  'd',
#  'they',
#  'shou',
#  'd',
#  'not',
#  'and',
#  'we',
#  'shall',
#  'then',
#  'with',
#  'God',
#  's',
#  'Blessing',
#  'prevent',
#  'all',
#  'the',
#  'mischief',
#  'they',
#  'intend',
#  'You',
#  'may',
#  'judge',
#  'by',
#  'the',
#  'late',
#  'Treason',
#  'in',
#  'the',
#  'North',
#  'for',
#  'which',
#  'so',
#  'many',
#  'Men',
#  'have',
#  'been',
#  'executed',
#  'how',
#  'active',
#  'the',
#  'Spirits',
#  'of',
#  'many',
#  'of',
#  'our',
#  'old',
#  'Enemies',
#  'still',
#  'are',
#  'notwithstanding',
#  'all',
#  'our',
#  'Mercy',
#  'I',
#  'do',
#  'assure',
#  'you']

# %%
def step2(text):
    corrected_text = [word for word in text if word.isalpha()]
    return corrected_text

# %%
toy_text = step2(toy_text)

# %% [markdown]
# <font color=darkgreen>
#
# ### 3. Lowercase

# %%
def step3(text):
    corrected_text = [word.lower() for word in text]
    return corrected_text

# %%
toy_text = step3(toy_text)

# %%
toy_text
# Out:
# ['ept',
#  'without',
#  'a',
#  'parliament',
#  'i',
#  'pray',
#  'watch',
#  'these',
#  'whisperers',
#  'all',
#  'you',
#  'can',
#  'as',
#  'men',
#  'who',
#  'use',
#  'their',
#  'utmost',
#  'endeavours',
#  'to',
#  'sow',
#  'jealousies',
#  'between',
#  'you',
#  'and',
#  'me',
#  'and',
#  'i',
#  'do',
#  'promise',
#  'you',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'me',
#  'and',
#  'i',
#  'do',
#  'promise',
#  'myself',
#  'they',
#  'shall',
#  'not',
#  'prevail',
#  'with',
#  'you',
#  'and',
#  'the',
#  'truth',
#  'is',
#  'we',
#  'are',
#  'both',
#  'concern',
#  'd',
#  'they',
#  'shou',
#  'd',
#  'not',
#  'and',
#  'we',
#  'shall',
#  'then',
#  'with',
#  'god',
#  's',
#  'blessing',
#  'prevent',
#  'all',
#  'the',
#  'mischief',
#  'they',
#  'intend',
#  'you',
#  'may',
#  'judge',
#  'by',
#  'the',
#  'late',
#  'treason',
#  'in',
#  'the',
#  'north',
#  'for',
#  'which',
#  'so',
#  'many',
#  'men',
#  'have',
#  'been',
#  'executed',
#  'how',
#  'active',
#  'the',
#  'spirits',
#  'of',
#  'many',
#  'of',
#  'our',
#  'old',
#  'enemies',
#  'still',
#  'are',
#  'notwithstanding',
#  'all',
#  'our',
#  'mercy',
#  'i',
#  'do',
#  'assure',
#  'you']

# %% [markdown]
# <font color=darkgreen>
#
# ### 5. Stop words
#
# ***preload as well as customizationble stop words***

# %%
#from datacamp; custom stop words list
english_stops = [
 'i',
 'me',
 'my',
 'myself',
 'we',
 'our',
 'ours',
 'ourselves',
 'you',
 'your',
 'yours',
 'yourself',
 'yourselves',
 'he',
 'him',
 'his',
 'himself',
 'she',
 'her',
 'hers',
 'herself',
 'it',
 'its',
 'itself',
 'they',
 'them',
 'their',
 'theirs',
 'themselves',
 'what',
 'which',
 'who',
 'whom',
 'this',
 'that',
 'these',
 'those',
 'am',
 'is',
 'are',
 'was',
 'were',
 'be',
 'been',
 'being',
 'have',
 'has',
 'had',
 'having',
 'do',
 'does',
 'did',
 'doing',
 'a',
 'an',
 'the',
 'and',
 'but',
 'if',
 'or',
 'because',
 'as',
 'until',
 'while',
 'of',
 'at',
 'by',
 'for',
 'with',
 'about',
 'against',
 'between',
 'into',
 'through',
 'during',
 'before',
 'after',
 'above',
 'below',
 'to',
 'from',
 'up',
 'down',
 'in',
 'out',
 'on',
 'off',
 'over',
 'under',
 'again',
 'further',
 'then',
 'once',
 'here',
 'there',
 'when',
 'where',
 'why',
 'how',
 'all',
 'any',
 'both',
 'each',
 'few',
 'more',
 'most',
 'other',
 'some',
 'such',
 'no',
 'nor',
 'not',
 'only',
 'own',
 'same',
 'so',
 'than',
 'too',
 'very',
 's',
 't',
 'can',
 'will',
 'just',
 'don',
 'should',
 'now',
 'd',
 'll',
 'm',
 'o',
 're',
 've',
 'y',
 'ain',
 'aren',
 'couldn',
 'didn',
 'doesn',
 'hadn',
 'hasn',
 'haven',
 'isn',
 'ma',
 'mightn',
 'mustn',
 'needn',
 'shan',
 'shouldn',
 'wasn',
 'weren',
 'won',
 'wouldn'
 ]

# %%
from nltk.corpus import stopwords
set(stopwords.words('english'))
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
# assumes that words are tokenized in a list

def step5(text):
    tokens_sans_stops = [word for word in tokens if word not in english_stops]
    return tokens_sans_stops

# %%
toy_text = step5(toy_text)

# %% [markdown]
# <font color=darkgreen>
#
# ### 4. Stem: reduce down to base words
#
# #### Goals of stemming:
#
# - Reduce dimensionality
# - Reduce noise
# - Increase human interpretability
# - Completely fails for some languages...
#
# Two methods:
#
# - Stemming (approximation of lemmatization) removes the end of words (use for old English for instance)
# - Lemmatization uses a dictionary to try to match to known base (good for OCR text?)

# %%
import nltk.stem
dir(nltk.stem)
# Out:
# ['ISRIStemmer',
#  'LancasterStemmer',
#  'PorterStemmer',
#  'RSLPStemmer',
#  'RegexpStemmer',
#  'SnowballStemmer',
#  'StemmerI',
#  'WordNetLemmatizer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'api',
#  'isri',
#  'lancaster',
#  'porter',
#  'regexp',
#  'rslp',
#  'snowball',
#  'util',
#  'wordnet']

# %% [markdown]
# <font color=darkgreen>
# #### 4a. Lancaster Stemer
#
# Lancaster is the "most aggressive" and shortens anything to a base that it might think worth doing unless it can directly find a base-word. Can create meaningless shortened words.
#
# Paice, Chris D. “Another Stemmer.” ACM SIGIR Forum 24.3 (1990): 56-61.

# %%
from nltk.stem import LancasterStemmer
ls = LancasterStemmer()

word_list = ['maximum','presumably','multiply','provision','owed','ear','saying','crying','string','meant','cement']

for word in word_list:
    print(ls.stem(word))
# Out:
# maxim
# presum
# multiply
# provid
# ow
# ear
# say
# cry
# string
# meant
# cem

# %%
[ls.stem(word) for word in toy_text][:10]
# Out:
# ['the', 'four', 'parlia', 'charl', 'ii', ':', 'first', 'sess', '(', '3']

# %% [markdown]
# <font color=darkgreen>
# #### 4b. Porter Stemer
#
# The "least aggressive" as it only goes after known 'endings.'
#
# Porter, M. “An algorithm for suffix stripping.” Program 14.3 (1980): 130-137.

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

for word in word_list:
    print(ps.stem(word))
# Out:
# maximum
# presum
# multipli
# provis
# owe
# ear
# say
# cri
# string
# meant
# cement

# %%
[ps.stem(word) for word in toy_text][:10]
# Out:
# ['the',
#  'fourth',
#  'parliament',
#  'charl',
#  'II',
#  ':',
#  'first',
#  'session',
#  '(',
#  '3']

# %% [markdown]
# <font color=darkgreen>
# #### 4c. Snowball Stemer (aka Porter2)
#
# 'Just right'? Uses a dictionary to try to stop overly aggresive stemming while still relying on a simple heuristic to drop the end of each word.
#
# http://www.nltk.org/_modules/nltk/stem/snowball.html

# %%
dir(nltk.stem.snowball)
# Out:
# ['ArabicStemmer',
#  'DanishStemmer',
#  'DutchStemmer',
#  'EnglishStemmer',
#  'FinnishStemmer',
#  'FrenchStemmer',
#  'GermanStemmer',
#  'HungarianStemmer',
#  'ItalianStemmer',
#  'NorwegianStemmer',
#  'PorterStemmer',
#  'PortugueseStemmer',
#  'RomanianStemmer',
#  'RussianStemmer',
#  'SnowballStemmer',
#  'SpanishStemmer',
#  'StemmerI',
#  'SwedishStemmer',
#  '_LanguageSpecificStemmer',
#  '_ScandinavianStemmer',
#  '_StandardStemmer',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'compat',
#  'demo',
#  'input',
#  'porter',
#  'prefix_replace',
#  'print_function',
#  're',
#  'stopwords',
#  'suffix_replace',
#  'unicode_literals']

# %%
from nltk.stem.snowball import EnglishStemmer
ss = EnglishStemmer()

for word in word_list:
    print(ss.stem(word))
# Out:
# maximum
# presum
# multipli
# provis
# owe
# ear
# say
# cri
# string
# meant
# cement

# %%
[ss.stem(word) for word in toy_text][:10]
# Out:
# ['the',
#  'fourth',
#  'parliament',
#  'charl',
#  'ii',
#  ':',
#  'first',
#  'session',
#  '(',
#  '3']

# %% [markdown]
# <font color=darkgreen>
# #### 4d. Lemmatization
#
# Uses WordNet, a lexical database of the English language assembled by psychologists at Princeton in late 80s, and a parts of speech tagger to identify base word. Computationally intensive.
#
# https://en.wikipedia.org/wiki/WordNet

# %%
from nltk.stem import WordNetLemmatizer
wl = WordNetLemmatizer()

for word in word_list:
    print(wl.lemmatize(word))
    
# %time #ipython magic command to time out how long cell takes
# Out:
# maximum
# presumably
# multiply
# provision
# owed
# ear
# saying
# cry
# string
# meant
# cement
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs

# %%
import pandas as pd

pd.DataFrame({
    'word_list':word_list,
    'lancaster_stemmer':[ls.stem(word) for word in word_list],
    'porter_stemmer':[ps.stem(word) for word in word_list],
    'snowball_stemmer':[ss.stem(word) for word in word_list],
    'wordnet_lemmatize':[wl.lemmatize(word) for word in word_list]    
}
)
# Out:
#    lancaster_stemmer porter_stemmer snowball_stemmer   word_list  \
# 0              maxim        maximum          maximum     maximum
# 1             presum         presum           presum  presumably
# 2           multiply       multipli         multipli    multiply
# 3             provid         provis           provis   provision
# 4                 ow            owe              owe        owed
# 5                ear            ear              ear         ear
# 6                say            say              say      saying
# 7                cry            cri              cri      crying
# 8             string         string           string      string
# 9              meant          meant            meant       meant
# 10               cem         cement           cement      cement
#
#    wordnet_lemmatize
# 0            maximum
# 1         presumably
# 2           multiply
# 3          provision
# 4               owed
# 5                ear
# 6             saying
# 7                cry
# 8             string
# 9              meant
# 10            cement

# %%
#I'm going with snowball because my 18th century English is probably not going to do well with a modern dictionary.

toy_text = [ss.stem(word) for word in toy_text]

# %% [markdown]
# <font color=darkgreen>
#
# ### 6. N-gram size

# %%
import nltk

bigrm = nltk.bigrams(toy_text)
print(list(bigrm))
# Out:
# [('the', 'fourth'), ('fourth', 'parliament'), ('parliament', 'charl'), ('charl', 'ii'), ('ii', ':'), (':', 'first'), ('first', 'session'), ('session', '('), ('(', '3'), ('3', '5'), ('5', ')'), (')', '-'), ('-', 'begin'), ('begin', '12'), ('12', '/'), ('/', '11'), ('11', '/'), ('/', '1680')]

# %% [markdown]
# <font color=darkgreen>
#
# ### 7. Infrequent terms removal
#
# Words that appear less than 1% of the time may not be useful in interpretation (n.b. but finding particular proper nouns can be quite meaningful).
#
# This has to be done across a corpus.

# %%
from collections import Counter 

#Counter produces a tuple of two lists
pd.DataFrame(Counter(toy_text).most_common(), columns=["word", "frequency"])
# Out:
#           word  frequency
# 0            /          2
# 1          the          1
# 2       fourth          1
# 3   parliament          1
# 4        charl          1
# 5           ii          1
# 6            :          1
# 7        first          1
# 8      session          1
# 9            (          1
# 10           3          1
# 11           5          1
# 12           )          1
# 13           -          1
# 14       begin          1
# 15          12          1
# 16          11          1
# 17        1680          1

# %%
def step0(text):
    corrected_text = text.replace('\\n', ' ').replace('\r', '').replace('\t', '').replace("\\","").replace("-",'')
    #corrected_text = corrected_text.replace('The History and Proceedings of the House of Commons: Volume 1, \\
    #1660-1680. Originally published by Chandler, London, 1742.', '')
    
    #DONT COPY THIS PART OF TEXT
    corrected_text = corrected_text[220:] #removes junk text from start of each page
    corrected_text = corrected_text[:-50] #removes junk at very end of each proceeding
    return corrected_text

# %%
#William and Mary's reign

from nltk.tokenize import wordpunct_tokenize

#splits on white space and on punctuation + step0
tokens = wordpunct_tokenize(step0(df_monarch.loc[4,'proceedings']))
#remove punctuation
tokens = step1(tokens)
#numbers
tokens = step2(tokens)
#lowercase
tokens = step3(tokens)
#remove stopwords
tokens = step5(tokens)

len(set(tokens))
# Out:
# 9920

# %%
one_precent_wm = len(set(tokens)) * .01
one_precent_wm
# Out:
# 99.2

# %%
Counter(tokens).most_common()[:100]
# Out:
# [('majesty', 2442),
#  ('house', 2381),
#  ('upon', 1480),
#  ('said', 1242),
#  ('commons', 1186),
#  ('made', 963),
#  ('mr', 915),
#  ('act', 900),
#  ('great', 840),
#  ('parliament', 835),
#  ('lords', 817),
#  ('time', 751),
#  ('may', 721),
#  ('would', 682),
#  ('bill', 641),
#  ('shall', 639),
#  ('one', 619),
#  ('year', 579),
#  ('several', 563),
#  ('day', 537),
#  ('public', 524),
#  ('committee', 494),
#  ('commissioners', 438),
#  ('address', 437),
#  ('right', 437),
#  ('l', 437),
#  ('england', 422),
#  ('give', 411),
#  ('first', 411),
#  ('two', 405),
#  ('make', 404),
#  ('law', 401),
#  ('hath', 399),
#  ('war', 388),
#  ('given', 379),
#  ('queen', 376),
#  ('order', 376),
#  ('service', 374),
#  ('whole', 362),
#  ('might', 358),
#  ('case', 357),
#  ('last', 352),
#  ('money', 351),
#  ('part', 349),
#  ('brought', 348),
#  ('take', 346),
#  ('us', 344),
#  ('read', 331),
#  ('persons', 331),
#  ('good', 329),
#  ('resolved', 327),
#  ('also', 320),
#  ('granted', 320),
#  ('presented', 318),
#  ('hundred', 315),
#  ('pleased', 315),
#  ('duties', 310),
#  ('sir', 303),
#  ('account', 301),
#  ('lord', 297),
#  ('must', 294),
#  ('think', 288),
#  ('action', 287),
#  ('present', 286),
#  ('person', 284),
#  ('without', 283),
#  ('king', 280),
#  ('thousand', 279),
#  ('since', 275),
#  ('taken', 275),
#  ('many', 273),
#  ('much', 269),
#  ('next', 269),
#  ('could', 267),
#  ('cannot', 266),
#  ('peace', 266),
#  ('ordered', 265),
#  ('lordships', 265),
#  ('laid', 260),
#  ('yet', 257),
#  ('every', 257),
#  ('per', 252),
#  ('agreed', 251),
#  ('resolutions', 249),
#  ('duty', 248),
#  ('put', 247),
#  ('following', 245),
#  ('kingdom', 245),
#  ('pounds', 243),
#  ('men', 243),
#  ('sum', 242),
#  ('consideration', 240),
#  ('question', 240),
#  ('late', 238),
#  ('trade', 235),
#  ('gentlemen', 232),
#  ('necessary', 231),
#  ('answer', 229),
#  ('well', 229),
#  ('subjects', 227)]

# %%
#list comprehension to get the 99% used.
[token for token, count in Counter(tokens).most_common()][:9820]
# Out:
# ['majesty',
#  'house',
#  'upon',
#  'said',
#  'commons',
#  'made',
#  'mr',
#  'act',
#  'great',
#  'parliament',
#  'lords',
#  'time',
#  'may',
#  'would',
#  'bill',
#  'shall',
#  'one',
#  'year',
#  'several',
#  'day',
#  'public',
#  'committee',
#  'commissioners',
#  'address',
#  'right',
#  'l',
#  'england',
#  'give',
#  'first',
#  'two',
#  'make',
#  'law',
#  'hath',
#  'war',
#  'given',
#  'queen',
#  'order',
#  'service',
#  'whole',
#  'might',
#  'case',
#  'last',
#  'money',
#  'part',
#  'brought',
#  'take',
#  'us',
#  'read',
#  'persons',
#  'good',
#  'resolved',
#  'also',
#  'granted',
#  'presented',
#  'hundred',
#  'pleased',
#  'duties',
#  'sir',
#  'account',
#  'lord',
#  'must',
#  'think',
#  'action',
#  'present',
#  'person',
#  'without',
#  'king',
#  'thousand',
#  'since',
#  'taken',
#  'many',
#  'much',
#  'next',
#  'could',
#  'cannot',
#  'peace',
#  'ordered',
#  'lordships',
#  'laid',
#  'yet',
#  'every',
#  'per',
#  'agreed',
#  'resolutions',
#  'duty',
#  'put',
#  'following',
#  'kingdom',
#  'pounds',
#  'men',
#  'sum',
#  'consideration',
#  'question',
#  'late',
#  'trade',
#  'gentlemen',
#  'necessary',
#  'answer',
#  'well',
#  'subjects',
#  'church',
#  'general',
#  'spain',
#  'scotland',
#  'done',
#  'paid',
#  'matter',
#  'power',
#  'relating',
#  'members',
#  'france',
#  'years',
#  'treaty',
#  'never',
#  'people',
#  'officers',
#  'therefore',
#  'reason',
#  'interest',
#  'reign',
#  'reported',
#  'whether',
#  'ought',
#  'proper',
#  'judgment',
#  'report',
#  'court',
#  'government',
#  'return',
#  'new',
#  'sent',
#  'making',
#  'allies',
#  'another',
#  'supply',
#  'royal',
#  'three',
#  'britain',
#  'resolution',
#  'state',
#  'received',
#  'according',
#  'man',
#  'appointed',
#  'petition',
#  'particular',
#  'effectual',
#  'accompts',
#  'houses',
#  'better',
#  'care',
#  'privileges',
#  'thought',
#  'proceedings',
#  'thing',
#  'thereof',
#  'till',
#  'crown',
#  'second',
#  'ever',
#  'pay',
#  'exchequer',
#  'came',
#  'bring',
#  'occasion',
#  'writ',
#  'charge',
#  'bills',
#  'accordingly',
#  'john',
#  'vote',
#  'office',
#  'opinion',
#  'others',
#  'use',
#  'consider',
#  'forces',
#  'duke',
#  'greatbritain',
#  'tho',
#  'find',
#  'earl',
#  'william',
#  'passed',
#  'say',
#  'come',
#  'humble',
#  'manner',
#  'always',
#  'laws',
#  'nothing',
#  'privilege',
#  'portugal',
#  'speaker',
#  'satisfaction',
#  'place',
#  'election',
#  'farther',
#  'leave',
#  'accounts',
#  'way',
#  'acts',
#  'union',
#  'london',
#  'army',
#  'gracious',
#  'means',
#  'session',
#  'elections',
#  'lay',
#  'due',
#  'afterwards',
#  'five',
#  'payment',
#  'gave',
#  'like',
#  'rights',
#  'number',
#  'mentioned',
#  'desire',
#  'nation',
#  'six',
#  'entitled',
#  'support',
#  'succession',
#  'towards',
#  'imported',
#  'company',
#  'error',
#  'common',
#  'humbly',
#  'c',
#  'far',
#  'long',
#  'committed',
#  'honour',
#  'protestant',
#  'continued',
#  'thanks',
#  'receive',
#  'grand',
#  'viz',
#  'thereupon',
#  'speech',
#  'hope',
#  'goods',
#  'allowed',
#  'end',
#  'motion',
#  'tis',
#  'troops',
#  'french',
#  'navy',
#  'cause',
#  'true',
#  'likewise',
#  'matters',
#  'foreign',
#  'st',
#  'peers',
#  'clause',
#  'taking',
#  'seven',
#  'judges',
#  'delivered',
#  'esq',
#  'liberty',
#  'four',
#  'fit',
#  'therein',
#  'raising',
#  'carried',
#  'certain',
#  'within',
#  'already',
#  'county',
#  'heard',
#  'cases',
#  'debate',
#  'sums',
#  'security',
#  'third',
#  'hands',
#  'words',
#  'god',
#  'supplies',
#  'private',
#  'obliged',
#  'country',
#  'amendments',
#  'provided',
#  'pass',
#  'appear',
#  'regiments',
#  'lie',
#  'know',
#  'member',
#  'honourable',
#  'either',
#  'reasons',
#  'even',
#  'justice',
#  'prevent',
#  'secretary',
#  'found',
#  'appears',
#  'resolv',
#  'debts',
#  'happy',
#  'set',
#  'greatest',
#  'ministers',
#  'directions',
#  'courts',
#  'constitution',
#  'enemies',
#  'sufficient',
#  'notice',
#  'december',
#  'concerned',
#  'advantage',
#  'concern',
#  'liberties',
#  'contrary',
#  'regiment',
#  'contract',
#  'called',
#  'desired',
#  'best',
#  'free',
#  'subject',
#  'shillings',
#  'officer',
#  'breach',
#  'believe',
#  'particularly',
#  'commission',
#  'parts',
#  'kingdoms',
#  'fn',
#  'took',
#  'serve',
#  'continue',
#  'religion',
#  'june',
#  'zeal',
#  'abroad',
#  'relation',
#  'expence',
#  'letter',
#  'though',
#  'authority',
#  'purpose',
#  'commerce',
#  'pursuant',
#  'see',
#  'among',
#  'go',
#  'terms',
#  'remedy',
#  'endeavours',
#  'assembled',
#  'acquainted',
#  'march',
#  'ships',
#  'orders',
#  'council',
#  'encouragement',
#  'method',
#  'established',
#  'lordship',
#  'least',
#  'message',
#  'body',
#  'days',
#  'course',
#  'consequence',
#  'instances',
#  'conference',
#  'places',
#  'additional',
#  'whatsoever',
#  'damages',
#  'former',
#  'things',
#  'nature',
#  'articles',
#  'paper',
#  'carrying',
#  'effect',
#  'ways',
#  'treaties',
#  'gentleman',
#  'little',
#  'referred',
#  'follows',
#  'james',
#  'services',
#  'practice',
#  'concerning',
#  'oath',
#  'amendment',
#  'otherwise',
#  'jurisdiction',
#  'april',
#  'commonlaw',
#  'electors',
#  'applied',
#  'utmost',
#  'doubt',
#  'securing',
#  'still',
#  'extraordinary',
#  'assent',
#  'fund',
#  'cent',
#  'english',
#  'preventing',
#  'whose',
#  'determine',
#  'assure',
#  'arms',
#  'returned',
#  'known',
#  'states',
#  'statesgeneral',
#  'offices',
#  'declared',
#  'except',
#  'papers',
#  'grant',
#  'dutiful',
#  'elected',
#  'printed',
#  'marlborough',
#  'majority',
#  'thomas',
#  'instance',
#  'merchants',
#  'determination',
#  'sensible',
#  'respect',
#  'regard',
#  'command',
#  'false',
#  'trust',
#  'party',
#  'judge',
#  'treasurer',
#  'continuing',
#  'intended',
#  'loss',
#  'raise',
#  'land',
#  'went',
#  'directed',
#  'notwithstanding',
#  'warrant',
#  'designs',
#  'greater',
#  'occasions',
#  'besides',
#  'negative',
#  'examine',
#  'able',
#  'enable',
#  'thereby',
#  'prince',
#  'let',
#  'annum',
#  'offered',
#  'allow',
#  'issued',
#  'provision',
#  'pence',
#  'chancellor',
#  'table',
#  'payable',
#  'future',
#  'less',
#  'elector',
#  'cloathing',
#  'maintain',
#  'neither',
#  'ill',
#  'shew',
#  'fully',
#  'high',
#  'left',
#  'charles',
#  'secure',
#  'customs',
#  'used',
#  'examination',
#  'loyal',
#  'times',
#  'term',
#  'offence',
#  'determined',
#  'declaration',
#  'safety',
#  'writs',
#  'measures',
#  'full',
#  'respective',
#  'july',
#  'revenue',
#  'months',
#  'name',
#  'granting',
#  'treasury',
#  'examined',
#  'flanders',
#  'payments',
#  'danger',
#  'establishment',
#  'endeavour',
#  'proportion',
#  'ten',
#  'eight',
#  'charged',
#  'pound',
#  'behalf',
#  'half',
#  'soon',
#  'favour',
#  'aforesaid',
#  'guilty',
#  'carry',
#  'represent',
#  'actions',
#  'month',
#  'robert',
#  'wanting',
#  'sovereign',
#  'home',
#  'formerly',
#  'enemy',
#  'august',
#  'express',
#  'reading',
#  'settled',
#  'advantages',
#  'giving',
#  'entirely',
#  'possible',
#  'affairs',
#  'auditor',
#  'business',
#  'relief',
#  'together',
#  'affection',
#  'raised',
#  'effectually',
#  'bringing',
#  'managers',
#  'agree',
#  'dissenters',
#  'beginning',
#  'immediately',
#  'foot',
#  'throne',
#  'clerk',
#  'westminster',
#  'force',
#  'point',
#  'dispatch',
#  'issue',
#  'custody',
#  'wines',
#  'emperor',
#  'contracts',
#  'proposed',
#  'prove',
#  'beg',
#  'entire',
#  'votes',
#  'declare',
#  'considerable',
#  'whereby',
#  'statute',
#  'walpole',
#  'january',
#  'uses',
#  'rate',
#  'assurances',
#  'faithful',
#  'europe',
#  'success',
#  'work',
#  'city',
#  'abuses',
#  'poor',
#  'weight',
#  'apply',
#  'proceed',
#  'safe',
#  'lately',
#  'double',
#  'manufactures',
#  'february',
#  'united',
#  'prisoners',
#  'corpus',
#  'estimate',
#  'admitted',
#  'nine',
#  'dangerous',
#  'prejudice',
#  'article',
#  'habeas',
#  'hanover',
#  'reasonable',
#  'considered',
#  'employed',
#  'examining',
#  'borough',
#  'near',
#  'westminsterhall',
#  'paying',
#  'practices',
#  'confidence',
#  'want',
#  'stand',
#  'ancient',
#  'town',
#  'ready',
#  'plain',
#  'books',
#  'principal',
#  'colonel',
#  'ireland',
#  'lands',
#  'plantations',
#  'tobacco',
#  'methods',
#  'precedent',
#  'usage',
#  'execution',
#  'open',
#  'prosecution',
#  'proceeded',
#  'refused',
#  'injury',
#  'look',
#  'complaint',
#  'amongst',
#  'grace',
#  'reserved',
#  'seems',
#  'equal',
#  'twenty',
#  'discharge',
#  'damage',
#  'met',
#  'representation',
#  'hearty',
#  'graciously',
#  'obtain',
#  'wherein',
#  'record',
#  'happiness',
#  'offer',
#  'kind',
#  'enquire',
#  'thus',
#  'entered',
#  'petitions',
#  'yearly',
#  'returns',
#  'call',
#  'civil',
#  'preserve',
#  'management',
#  'acquaint',
#  'depend',
#  'sea',
#  'receipt',
#  'henry',
#  'unanimously',
#  'serjeant',
#  'spanish',
#  'observe',
#  'funds',
#  'however',
#  'glorious',
#  'letters',
#  'scandalous',
#  'hopes',
#  'concurrence',
#  'debt',
#  'fourth',
#  'passing',
#  'appeared',
#  'sense',
#  'usual',
#  'none',
#  'landforces',
#  'sole',
#  'millions',
#  'credit',
#  'stock',
#  'attending',
#  'plaintiff',
#  'accompt',
#  'measure',
#  'difficulties',
#  'dominions',
#  'shewn',
#  'unless',
#  'rest',
#  'seem',
#  'settling',
#  'churches',
#  'insisted',
#  'especially',
#  'lost',
#  'virtue',
#  'attended',
#  'speedy',
#  'opportunity',
#  'rates',
#  'informed',
#  'remain',
#  'judicature',
#  'merchandizes',
#  'africa',
#  'ii',
#  'servants',
#  'copy',
#  'friends',
#  'away',
#  'employment',
#  'design',
#  'spiritual',
#  'relates',
#  'preservation',
#  'pretended',
#  'custom',
#  'necessity',
#  'parliaments',
#  'application',
#  'woollen',
#  'benefit',
#  'spoke',
#  'proceeding',
#  'employ',
#  'addresses',
#  'pretender',
#  'impositions',
#  'port',
#  'maintaining',
#  'longer',
#  'direct',
#  'insist',
#  'advanced',
#  'precedents',
#  'apprehend',
#  'fifty',
#  'large',
#  'obtained',
#  'estates',
#  'furnish',
#  'paymaster',
#  'provisions',
#  'frauds',
#  'conclusion',
#  'praying',
#  'imperial',
#  'evidence',
#  'happen',
#  'correspondence',
#  'follow',
#  'originally',
#  'temporal',
#  'condition',
#  'monarchy',
#  'laying',
#  'seamen',
#  'back',
#  'victualling',
#  'mean',
#  'duly',
#  'instruction',
#  'exceeding',
#  'equivalent',
#  'conduct',
#  'bishop',
#  'published',
#  'goodness',
#  'observed',
#  'continuance',
#  'head',
#  'satisfied',
#  'often',
#  'procure',
#  'lies',
#  'attempt',
#  'exported',
#  'de',
#  'assistance',
#  'holland',
#  'pleasure',
#  'consequences',
#  'become',
#  'wisdom',
#  'michaelmas',
#  'suppose',
#  'wharton',
#  'blessing',
#  'value',
#  'sit',
#  'particulars',
#  'hand',
#  'represented',
#  'forty',
#  'punish',
#  'book',
#  'freedom',
#  'highly',
#  'depending',
#  'burden',
#  'charges',
#  'world',
#  'moneys',
#  'countries',
#  'sbench',
#  'please',
#  'bank',
#  'whereupon',
#  'charter',
#  'petitioners',
#  'salt',
#  'engrossed',
#  'instructions',
#  'interests',
#  'progress',
#  'send',
#  'suffer',
#  'signed',
#  'title',
#  'penalties',
#  'pretence',
#  'conceive',
#  'penalty',
#  'circumstances',
#  'deliver',
#  'liable',
#  'direction',
#  'revenues',
#  'parliamentary',
#  'draw',
#  'subsidies',
#  'board',
#  'debentures',
#  'campaign',
#  'lottery',
#  'coming',
#  'exportation',
#  'gives',
#  'mention',
#  'kept',
#  'affair',
#  'whereof',
#  'punishment',
#  'fact',
#  'whatever',
#  'share',
#  'form',
#  'importance',
#  'thence',
#  'alliance',
#  'observations',
#  'stating',
#  'regulating',
#  'expences',
#  'produce',
#  'side',
#  'prerogative',
#  'single',
#  'injured',
#  'possession',
#  'determining',
#  'garrisons',
#  'bar',
#  'truly',
#  'whereas',
#  'receiving',
#  'consent',
#  'cities',
#  'eighth',
#  'says',
#  'allowance',
#  'easy',
#  'concluded',
#  'list',
#  'recommend',
#  'grounded',
#  'preserving',
#  'rule',
#  'annuities',
#  'wish',
#  'complete',
#  'short',
#  'forth',
#  'room',
#  'attend',
#  'occasional',
#  'conformity',
#  'content',
#  'provide',
#  'profit',
#  'corporation',
#  'undoubted',
#  'hear',
#  'sure',
#  'complained',
#  'trial',
#  'building',
#  'prosecuted',
#  'importation',
#  'arise',
#  'arising',
#  'malt',
#  'parchment',
#  'brandy',
#  'tuesday',
#  'deposition',
#  'death',
#  'deposed',
#  'deficiency',
#  'posterity',
#  'speak',
#  'clergy',
#  'voted',
#  'certainly',
#  'indeed',
#  'heirs',
#  'added',
#  'argument',
#  'foundation',
#  'illegal',
#  'tell',
#  'chief',
#  'rolls',
#  'remembrancer',
#  'enquiry',
#  'appoint',
#  'causes',
#  'ground',
#  'repairing',
#  'marines',
#  'readily',
#  'forage',
#  'furnished',
#  'meet',
#  'prosecuting',
#  'promise',
#  'thank',
#  'comes',
#  'nemine',
#  'family',
#  'meeting',
#  'secondly',
#  'attempts',
#  'welfare',
#  'produced',
#  'discharged',
#  'voices',
#  'negociation',
#  'journals',
#  'drawn',
#  'wrong',
#  'stores',
#  'expected',
#  'sale',
#  'princes',
#  'chosen',
#  'engaged',
#  'november',
#  'expect',
#  'almost',
#  'contradicente',
#  'life',
#  'occasioned',
#  'twelve',
#  'frequently',
#  'ninth',
#  'proof',
#  'rather',
#  'difference',
#  'heavy',
#  'appropriated',
#  'amount',
#  'learned',
#  'remains',
#  'thoughts',
#  'arguments',
#  'reports',
#  'agent',
#  ...]

# %%
def step7(tokens):
    #ninety_nine = round(len(set(tokens)) * .99)
    tokens = [token for token, count in Counter(tokens).most_common()][:round(len(set(tokens)) * .99)]
    return tokens

# %%
step7(tokens)
# Out:
# ['majesty',
#  'house',
#  'upon',
#  'said',
#  'commons',
#  'made',
#  'mr',
#  'act',
#  'great',
#  'parliament',
#  'lords',
#  'time',
#  'may',
#  'would',
#  'bill',
#  'shall',
#  'one',
#  'year',
#  'several',
#  'day',
#  'public',
#  'committee',
#  'commissioners',
#  'address',
#  'right',
#  'l',
#  'england',
#  'give',
#  'first',
#  'two',
#  'make',
#  'law',
#  'hath',
#  'war',
#  'given',
#  'queen',
#  'order',
#  'service',
#  'whole',
#  'might',
#  'case',
#  'last',
#  'money',
#  'part',
#  'brought',
#  'take',
#  'us',
#  'read',
#  'persons',
#  'good',
#  'resolved',
#  'also',
#  'granted',
#  'presented',
#  'hundred',
#  'pleased',
#  'duties',
#  'sir',
#  'account',
#  'lord',
#  'must',
#  'think',
#  'action',
#  'present',
#  'person',
#  'without',
#  'king',
#  'thousand',
#  'since',
#  'taken',
#  'many',
#  'much',
#  'next',
#  'could',
#  'cannot',
#  'peace',
#  'ordered',
#  'lordships',
#  'laid',
#  'yet',
#  'every',
#  'per',
#  'agreed',
#  'resolutions',
#  'duty',
#  'put',
#  'following',
#  'kingdom',
#  'pounds',
#  'men',
#  'sum',
#  'consideration',
#  'question',
#  'late',
#  'trade',
#  'gentlemen',
#  'necessary',
#  'answer',
#  'well',
#  'subjects',
#  'church',
#  'general',
#  'spain',
#  'scotland',
#  'done',
#  'paid',
#  'matter',
#  'power',
#  'relating',
#  'members',
#  'france',
#  'years',
#  'treaty',
#  'never',
#  'people',
#  'officers',
#  'therefore',
#  'reason',
#  'interest',
#  'reign',
#  'reported',
#  'whether',
#  'ought',
#  'proper',
#  'judgment',
#  'report',
#  'court',
#  'government',
#  'return',
#  'new',
#  'sent',
#  'making',
#  'allies',
#  'another',
#  'supply',
#  'royal',
#  'three',
#  'britain',
#  'resolution',
#  'state',
#  'received',
#  'according',
#  'man',
#  'appointed',
#  'petition',
#  'particular',
#  'effectual',
#  'accompts',
#  'houses',
#  'better',
#  'care',
#  'privileges',
#  'thought',
#  'proceedings',
#  'thing',
#  'thereof',
#  'till',
#  'crown',
#  'second',
#  'ever',
#  'pay',
#  'exchequer',
#  'came',
#  'bring',
#  'occasion',
#  'writ',
#  'charge',
#  'bills',
#  'accordingly',
#  'john',
#  'vote',
#  'office',
#  'opinion',
#  'others',
#  'use',
#  'consider',
#  'forces',
#  'duke',
#  'greatbritain',
#  'tho',
#  'find',
#  'earl',
#  'william',
#  'passed',
#  'say',
#  'come',
#  'humble',
#  'manner',
#  'always',
#  'laws',
#  'nothing',
#  'privilege',
#  'portugal',
#  'speaker',
#  'satisfaction',
#  'place',
#  'election',
#  'farther',
#  'leave',
#  'accounts',
#  'way',
#  'acts',
#  'union',
#  'london',
#  'army',
#  'gracious',
#  'means',
#  'session',
#  'elections',
#  'lay',
#  'due',
#  'afterwards',
#  'five',
#  'payment',
#  'gave',
#  'like',
#  'rights',
#  'number',
#  'mentioned',
#  'desire',
#  'nation',
#  'six',
#  'entitled',
#  'support',
#  'succession',
#  'towards',
#  'imported',
#  'company',
#  'error',
#  'common',
#  'humbly',
#  'c',
#  'far',
#  'long',
#  'committed',
#  'honour',
#  'protestant',
#  'continued',
#  'thanks',
#  'receive',
#  'grand',
#  'viz',
#  'thereupon',
#  'speech',
#  'hope',
#  'goods',
#  'allowed',
#  'end',
#  'motion',
#  'tis',
#  'troops',
#  'french',
#  'navy',
#  'cause',
#  'true',
#  'likewise',
#  'matters',
#  'foreign',
#  'st',
#  'peers',
#  'clause',
#  'taking',
#  'seven',
#  'judges',
#  'delivered',
#  'esq',
#  'liberty',
#  'four',
#  'fit',
#  'therein',
#  'raising',
#  'carried',
#  'certain',
#  'within',
#  'already',
#  'county',
#  'heard',
#  'cases',
#  'debate',
#  'sums',
#  'security',
#  'third',
#  'hands',
#  'words',
#  'god',
#  'supplies',
#  'private',
#  'obliged',
#  'country',
#  'amendments',
#  'provided',
#  'pass',
#  'appear',
#  'regiments',
#  'lie',
#  'know',
#  'member',
#  'honourable',
#  'either',
#  'reasons',
#  'even',
#  'justice',
#  'prevent',
#  'secretary',
#  'found',
#  'appears',
#  'resolv',
#  'debts',
#  'happy',
#  'set',
#  'greatest',
#  'ministers',
#  'directions',
#  'courts',
#  'constitution',
#  'enemies',
#  'sufficient',
#  'notice',
#  'december',
#  'concerned',
#  'advantage',
#  'concern',
#  'liberties',
#  'contrary',
#  'regiment',
#  'contract',
#  'called',
#  'desired',
#  'best',
#  'free',
#  'subject',
#  'shillings',
#  'officer',
#  'breach',
#  'believe',
#  'particularly',
#  'commission',
#  'parts',
#  'kingdoms',
#  'fn',
#  'took',
#  'serve',
#  'continue',
#  'religion',
#  'june',
#  'zeal',
#  'abroad',
#  'relation',
#  'expence',
#  'letter',
#  'though',
#  'authority',
#  'purpose',
#  'commerce',
#  'pursuant',
#  'see',
#  'among',
#  'go',
#  'terms',
#  'remedy',
#  'endeavours',
#  'assembled',
#  'acquainted',
#  'march',
#  'ships',
#  'orders',
#  'council',
#  'encouragement',
#  'method',
#  'established',
#  'lordship',
#  'least',
#  'message',
#  'body',
#  'days',
#  'course',
#  'consequence',
#  'instances',
#  'conference',
#  'places',
#  'additional',
#  'whatsoever',
#  'damages',
#  'former',
#  'things',
#  'nature',
#  'articles',
#  'paper',
#  'carrying',
#  'effect',
#  'ways',
#  'treaties',
#  'gentleman',
#  'little',
#  'referred',
#  'follows',
#  'james',
#  'services',
#  'practice',
#  'concerning',
#  'oath',
#  'amendment',
#  'otherwise',
#  'jurisdiction',
#  'april',
#  'commonlaw',
#  'electors',
#  'applied',
#  'utmost',
#  'doubt',
#  'securing',
#  'still',
#  'extraordinary',
#  'assent',
#  'fund',
#  'cent',
#  'english',
#  'preventing',
#  'whose',
#  'determine',
#  'assure',
#  'arms',
#  'returned',
#  'known',
#  'states',
#  'statesgeneral',
#  'offices',
#  'declared',
#  'except',
#  'papers',
#  'grant',
#  'dutiful',
#  'elected',
#  'printed',
#  'marlborough',
#  'majority',
#  'thomas',
#  'instance',
#  'merchants',
#  'determination',
#  'sensible',
#  'respect',
#  'regard',
#  'command',
#  'false',
#  'trust',
#  'party',
#  'judge',
#  'treasurer',
#  'continuing',
#  'intended',
#  'loss',
#  'raise',
#  'land',
#  'went',
#  'directed',
#  'notwithstanding',
#  'warrant',
#  'designs',
#  'greater',
#  'occasions',
#  'besides',
#  'negative',
#  'examine',
#  'able',
#  'enable',
#  'thereby',
#  'prince',
#  'let',
#  'annum',
#  'offered',
#  'allow',
#  'issued',
#  'provision',
#  'pence',
#  'chancellor',
#  'table',
#  'payable',
#  'future',
#  'less',
#  'elector',
#  'cloathing',
#  'maintain',
#  'neither',
#  'ill',
#  'shew',
#  'fully',
#  'high',
#  'left',
#  'charles',
#  'secure',
#  'customs',
#  'used',
#  'examination',
#  'loyal',
#  'times',
#  'term',
#  'offence',
#  'determined',
#  'declaration',
#  'safety',
#  'writs',
#  'measures',
#  'full',
#  'respective',
#  'july',
#  'revenue',
#  'months',
#  'name',
#  'granting',
#  'treasury',
#  'examined',
#  'flanders',
#  'payments',
#  'danger',
#  'establishment',
#  'endeavour',
#  'proportion',
#  'ten',
#  'eight',
#  'charged',
#  'pound',
#  'behalf',
#  'half',
#  'soon',
#  'favour',
#  'aforesaid',
#  'guilty',
#  'carry',
#  'represent',
#  'actions',
#  'month',
#  'robert',
#  'wanting',
#  'sovereign',
#  'home',
#  'formerly',
#  'enemy',
#  'august',
#  'express',
#  'reading',
#  'settled',
#  'advantages',
#  'giving',
#  'entirely',
#  'possible',
#  'affairs',
#  'auditor',
#  'business',
#  'relief',
#  'together',
#  'affection',
#  'raised',
#  'effectually',
#  'bringing',
#  'managers',
#  'agree',
#  'dissenters',
#  'beginning',
#  'immediately',
#  'foot',
#  'throne',
#  'clerk',
#  'westminster',
#  'force',
#  'point',
#  'dispatch',
#  'issue',
#  'custody',
#  'wines',
#  'emperor',
#  'contracts',
#  'proposed',
#  'prove',
#  'beg',
#  'entire',
#  'votes',
#  'declare',
#  'considerable',
#  'whereby',
#  'statute',
#  'walpole',
#  'january',
#  'uses',
#  'rate',
#  'assurances',
#  'faithful',
#  'europe',
#  'success',
#  'work',
#  'city',
#  'abuses',
#  'poor',
#  'weight',
#  'apply',
#  'proceed',
#  'safe',
#  'lately',
#  'double',
#  'manufactures',
#  'february',
#  'united',
#  'prisoners',
#  'corpus',
#  'estimate',
#  'admitted',
#  'nine',
#  'dangerous',
#  'prejudice',
#  'article',
#  'habeas',
#  'hanover',
#  'reasonable',
#  'considered',
#  'employed',
#  'examining',
#  'borough',
#  'near',
#  'westminsterhall',
#  'paying',
#  'practices',
#  'confidence',
#  'want',
#  'stand',
#  'ancient',
#  'town',
#  'ready',
#  'plain',
#  'books',
#  'principal',
#  'colonel',
#  'ireland',
#  'lands',
#  'plantations',
#  'tobacco',
#  'methods',
#  'precedent',
#  'usage',
#  'execution',
#  'open',
#  'prosecution',
#  'proceeded',
#  'refused',
#  'injury',
#  'look',
#  'complaint',
#  'amongst',
#  'grace',
#  'reserved',
#  'seems',
#  'equal',
#  'twenty',
#  'discharge',
#  'damage',
#  'met',
#  'representation',
#  'hearty',
#  'graciously',
#  'obtain',
#  'wherein',
#  'record',
#  'happiness',
#  'offer',
#  'kind',
#  'enquire',
#  'thus',
#  'entered',
#  'petitions',
#  'yearly',
#  'returns',
#  'call',
#  'civil',
#  'preserve',
#  'management',
#  'acquaint',
#  'depend',
#  'sea',
#  'receipt',
#  'henry',
#  'unanimously',
#  'serjeant',
#  'spanish',
#  'observe',
#  'funds',
#  'however',
#  'glorious',
#  'letters',
#  'scandalous',
#  'hopes',
#  'concurrence',
#  'debt',
#  'fourth',
#  'passing',
#  'appeared',
#  'sense',
#  'usual',
#  'none',
#  'landforces',
#  'sole',
#  'millions',
#  'credit',
#  'stock',
#  'attending',
#  'plaintiff',
#  'accompt',
#  'measure',
#  'difficulties',
#  'dominions',
#  'shewn',
#  'unless',
#  'rest',
#  'seem',
#  'settling',
#  'churches',
#  'insisted',
#  'especially',
#  'lost',
#  'virtue',
#  'attended',
#  'speedy',
#  'opportunity',
#  'rates',
#  'informed',
#  'remain',
#  'judicature',
#  'merchandizes',
#  'africa',
#  'ii',
#  'servants',
#  'copy',
#  'friends',
#  'away',
#  'employment',
#  'design',
#  'spiritual',
#  'relates',
#  'preservation',
#  'pretended',
#  'custom',
#  'necessity',
#  'parliaments',
#  'application',
#  'woollen',
#  'benefit',
#  'spoke',
#  'proceeding',
#  'employ',
#  'addresses',
#  'pretender',
#  'impositions',
#  'port',
#  'maintaining',
#  'longer',
#  'direct',
#  'insist',
#  'advanced',
#  'precedents',
#  'apprehend',
#  'fifty',
#  'large',
#  'obtained',
#  'estates',
#  'furnish',
#  'paymaster',
#  'provisions',
#  'frauds',
#  'conclusion',
#  'praying',
#  'imperial',
#  'evidence',
#  'happen',
#  'correspondence',
#  'follow',
#  'originally',
#  'temporal',
#  'condition',
#  'monarchy',
#  'laying',
#  'seamen',
#  'back',
#  'victualling',
#  'mean',
#  'duly',
#  'instruction',
#  'exceeding',
#  'equivalent',
#  'conduct',
#  'bishop',
#  'published',
#  'goodness',
#  'observed',
#  'continuance',
#  'head',
#  'satisfied',
#  'often',
#  'procure',
#  'lies',
#  'attempt',
#  'exported',
#  'de',
#  'assistance',
#  'holland',
#  'pleasure',
#  'consequences',
#  'become',
#  'wisdom',
#  'michaelmas',
#  'suppose',
#  'wharton',
#  'blessing',
#  'value',
#  'sit',
#  'particulars',
#  'hand',
#  'represented',
#  'forty',
#  'punish',
#  'book',
#  'freedom',
#  'highly',
#  'depending',
#  'burden',
#  'charges',
#  'world',
#  'moneys',
#  'countries',
#  'sbench',
#  'please',
#  'bank',
#  'whereupon',
#  'charter',
#  'petitioners',
#  'salt',
#  'engrossed',
#  'instructions',
#  'interests',
#  'progress',
#  'send',
#  'suffer',
#  'signed',
#  'title',
#  'penalties',
#  'pretence',
#  'conceive',
#  'penalty',
#  'circumstances',
#  'deliver',
#  'liable',
#  'direction',
#  'revenues',
#  'parliamentary',
#  'draw',
#  'subsidies',
#  'board',
#  'debentures',
#  'campaign',
#  'lottery',
#  'coming',
#  'exportation',
#  'gives',
#  'mention',
#  'kept',
#  'affair',
#  'whereof',
#  'punishment',
#  'fact',
#  'whatever',
#  'share',
#  'form',
#  'importance',
#  'thence',
#  'alliance',
#  'observations',
#  'stating',
#  'regulating',
#  'expences',
#  'produce',
#  'side',
#  'prerogative',
#  'single',
#  'injured',
#  'possession',
#  'determining',
#  'garrisons',
#  'bar',
#  'truly',
#  'whereas',
#  'receiving',
#  'consent',
#  'cities',
#  'eighth',
#  'says',
#  'allowance',
#  'easy',
#  'concluded',
#  'list',
#  'recommend',
#  'grounded',
#  'preserving',
#  'rule',
#  'annuities',
#  'wish',
#  'complete',
#  'short',
#  'forth',
#  'room',
#  'attend',
#  'occasional',
#  'conformity',
#  'content',
#  'provide',
#  'profit',
#  'corporation',
#  'undoubted',
#  'hear',
#  'sure',
#  'complained',
#  'trial',
#  'building',
#  'prosecuted',
#  'importation',
#  'arise',
#  'arising',
#  'malt',
#  'parchment',
#  'brandy',
#  'tuesday',
#  'deposition',
#  'death',
#  'deposed',
#  'deficiency',
#  'posterity',
#  'speak',
#  'clergy',
#  'voted',
#  'certainly',
#  'indeed',
#  'heirs',
#  'added',
#  'argument',
#  'foundation',
#  'illegal',
#  'tell',
#  'chief',
#  'rolls',
#  'remembrancer',
#  'enquiry',
#  'appoint',
#  'causes',
#  'ground',
#  'repairing',
#  'marines',
#  'readily',
#  'forage',
#  'furnished',
#  'meet',
#  'prosecuting',
#  'promise',
#  'thank',
#  'comes',
#  'nemine',
#  'family',
#  'meeting',
#  'secondly',
#  'attempts',
#  'welfare',
#  'produced',
#  'discharged',
#  'voices',
#  'negociation',
#  'journals',
#  'drawn',
#  'wrong',
#  'stores',
#  'expected',
#  'sale',
#  'princes',
#  'chosen',
#  'engaged',
#  'november',
#  'expect',
#  'almost',
#  'contradicente',
#  'life',
#  'occasioned',
#  'twelve',
#  'frequently',
#  'ninth',
#  'proof',
#  'rather',
#  'difference',
#  'heavy',
#  'appropriated',
#  'amount',
#  'learned',
#  'remains',
#  'thoughts',
#  'arguments',
#  'reports',
#  'agent',
#  ...]

# %% [markdown]
# ***
# ***

# %% [markdown]
# <font color=darkgreen>
#
# ## Illustrating the consequences

# %%
text = df_monarch.loc[4,'proceedings']

#splits on white space and on punctuation + step0 clean up
tokens = wordpunct_tokenize(step0(text))
    
#remove punctuation
tokens = step1(tokens)
    
#numbers
tokens = step2(tokens)
    
#lowercase
tokens = step3(tokens)
    
#remove stopwords
tokens = step5(tokens)

#pick words that across texts are not common
#rarer_words = Counter(list_all_cleaned).most_common()[1000:]
#tokens = [token for token, count in tokens if token in rarer_words]

#rare words removed
#tokens = step7(tokens)
    
#4: PICK A STEMMER

#'lancaster_stemmer'
#tokens = [ls.stem(token) for token in tokens]

#'porter_stemmer':
#tokens = [ps.stem(token) for token in tokens]

#'snowball stemmer:
#tokens = [ss.stem(token) for token in tokens]

#wordnet lemmatize
tokens = [wl.lemmatize(token) for token in tokens] 


#here, a little hack to grab after 500 [500:600]
freq_count = pd.DataFrame(Counter(tokens).most_common(), columns=["word", "frequency"])[:75]

# %%
import matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 10))
plt.bar(freq_count.index, freq_count['frequency'].values, color = "darkblue", alpha = 0.7, edgecolor="white")
plt.xticks(freq_count.index, freq_count['word'].values, rotation=90)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.grid()

plt.show()

# %% [markdown]
# ## Fun stuff to do at home later.

# %%
cleaned_monarchs = []

for proceeding in df_monarch['proceedings']:

    #splits on white space and on punctuation + step0 clean up
    tokens = wordpunct_tokenize(step0(proceeding))
    
    #remove punctuation
    tokens = step1(tokens)
    
    #numbers
    tokens = step2(tokens)
    
    #lowercase
    tokens = step3(tokens)
    
    #remove stopwords
    tokens = step5(tokens)
    
    #remove rare words
    #tokens = step7(tokens)

    #stem
    tokens = [wl.lemmatize(token) for token in tokens] 
    
    cleaned_monarchs.append(tokens)

# %%
nltk_monarchs = []

for list_tokens in cleaned_monarchs:
    
    tokens = nltk.Text(list_tokens)
    nltk_monarchs.append(tokens)

# %%
for text in nltk_monarchs:
    text.dispersion_plot(['war','tax','liberty'])

# %% [markdown]
# <font color=darkpurple>
#
# # **In-class exercise / homework**

# %% [markdown]
# <font color=darkgreen>
#
# ## The Grimmer and Stewart (2013) Bag of Words recipe:
#
# 1. All words: unigrams or Named Entity bigrams (e.g. "White House")
# 2. Lemmatization ("family, families, families' and familial become famili")
# 3. ... discard "punctuation, capitalization, very common words ('stop' words) or functiona words), and very uncommon words (words that appear only once or twice in the corpus and thus are unlikely to be discriminating). We typically remove words which appear in less than 1% and more than 99% of documents in the corpus..."

# %%
def BagOWordsR():
    '''
    Takes in a corpus (vector of strings), maybe some arguments, and performs the following steps:
    
    1. Removes all numbers, punctuation, exit characters, html artifacts
    2. Splits on white space to create a list of words (i.e. tokens)
    3. Lowercases all tokens
    4. Stem all tokens using _____ stemmer
    5. Remove stop words *from across the corpus*.
    6. Remove rare words *from across the corpus*.
    
    ALSO: prints a percentage of # of tokens changed.
    
    List of strings --> List of strings; Int.
    
    '''
