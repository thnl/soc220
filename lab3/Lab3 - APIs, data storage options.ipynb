# %% [markdown]
# <font color=darkred>
#
# # Soc220: Computational Text Analysis
# ## Lab3: APIs and data storage options
#
# <br>
#
# <img src="tillerson.png" alt="Drawing" style="width: 600px;"/>
#
# ***
#     2/7/2018
#     Zach Wehrwein

# %% [markdown]
# <font color=darkpurple>
#
# ### Solutions
#
# * 'class' in python is a default command use to program custom objects and methods, so that's why you use class_ in soup.

# %%
import re
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pickle
import json
import os

#change directory

# %%
# !cd /Users/zwehrwein/Dropbox/Coursework/2018Spring/soc220_spring2018/soc220-labs-draft/lab3/

# %%
#LIST OF SPEECH URLS


url = "http://www.presidency.ucsb.edu/sou.php"
req = requests.get(url,timeout=20) #always include a delay!
req.status_code
# Out:
# 200

# %%
req.html = req.text
soup = BeautifulSoup(req.html,"html.parser")

# %% [markdown]
# <img src="nixon.png" alt="Drawing" style="width: 600px;"/>
#
# ### Need to get right URLS as a result (just in the table).

# %%
#Get the right list of URLS
#VER12 gets us the main table and not the extra links
speech_url_list = []
for span in soup.find_all('td', class_="ver12"):
    #print(span)
    if len(span.find_all('a',href = re.compile('pid'))) > 0:
        link = span.find('a')['href']
        speech_url_list.append(link)
        print(link)
# Out:
# http://www.presidency.ucsb.edu/ws/index.php?pid=123408
# http://www.presidency.ucsb.edu/ws/index.php?pid=128921
# http://www.presidency.ucsb.edu/ws/index.php?pid=102826
# http://www.presidency.ucsb.edu/ws/index.php?pid=104596
# http://www.presidency.ucsb.edu/ws/index.php?pid=108031
# http://www.presidency.ucsb.edu/ws/index.php?pid=111174
# http://www.presidency.ucsb.edu/ws/index.php?pid=85753
# http://www.presidency.ucsb.edu/ws/index.php?pid=87433
# http://www.presidency.ucsb.edu/ws/index.php?pid=88928
# http://www.presidency.ucsb.edu/ws/index.php?pid=99000
# http://www.presidency.ucsb.edu/ws/index.php?pid=58746
# http://www.presidency.ucsb.edu/ws/index.php?pid=65090
# http://www.presidency.ucsb.edu/ws/index.php?pid=24446
# http://www.presidency.ucsb.edu/ws/index.php?pid=76301
# http://www.presidency.ucsb.edu/ws/index.php?pid=29643
# http://www.presidency.ucsb.edu/ws/index.php?pid=29644
# http://www.presidency.ucsb.edu/ws/index.php?pid=29645
# http://www.presidency.ucsb.edu/ws/index.php?pid=29646
# http://www.presidency.ucsb.edu/ws/index.php?pid=53358
# http://www.presidency.ucsb.edu/ws/index.php?pid=56280
# http://www.presidency.ucsb.edu/ws/index.php?pid=57577
# http://www.presidency.ucsb.edu/ws/index.php?pid=58708
# http://www.presidency.ucsb.edu/ws/index.php?pid=47232
# http://www.presidency.ucsb.edu/ws/index.php?pid=50409
# http://www.presidency.ucsb.edu/ws/index.php?pid=51634
# http://www.presidency.ucsb.edu/ws/index.php?pid=53091
# http://www.presidency.ucsb.edu/ws/index.php?pid=16660
# http://www.presidency.ucsb.edu/ws/index.php?pid=18095
# http://www.presidency.ucsb.edu/ws/index.php?pid=19253
# http://www.presidency.ucsb.edu/ws/index.php?pid=20544
# http://www.presidency.ucsb.edu/ws/index.php?pid=38069
# http://www.presidency.ucsb.edu/ws/index.php?pid=29442
# http://www.presidency.ucsb.edu/ws/index.php?pid=29435
# http://www.presidency.ucsb.edu/ws/index.php?pid=29436
# http://www.presidency.ucsb.edu/ws/index.php?pid=29437
# http://www.presidency.ucsb.edu/ws/index.php?pid=29438
# http://www.presidency.ucsb.edu/ws/index.php?pid=29431
# http://www.presidency.ucsb.edu/ws/index.php?pid=29432
# http://www.presidency.ucsb.edu/ws/index.php?pid=29433
# http://www.presidency.ucsb.edu/ws/index.php?pid=29434

# %%
len(speech_url_list)
# Out:
# 244

# %%
#create a new directory to store data.
dir_path = "sotu_speeches"
if os.path.exists(dir_path) == False:
    os.makedirs(dir_path)

os.chdir('sotu_speeches')
   
#print working directory
# !pwd
# Out:
# /Users/zwehrwein/Dropbox/Coursework/2018Spring/soc220_spring2018/Github/lab3/sotu_speeches/sotu_speeches/sotu_speeches

# %%
titles_speeches = []
text_of_speeches = []

for url in speech_url_list:
    
    #10x timeout
    req = requests.get(url,timeout=200)
    req.html = req.text
    soup = BeautifulSoup(req.html,"html.parser")
    
    #date
    try:
        date = soup.find('span', class_= 'docdate').get_text()
        #dates_of_speeches.append(date)
        #print('processed:',len(dates_of_speeches),date)
    except:
        print('FAIL ON DATE:',len(dates_of_speeches))
        
    #name
    try:
        name = soup.title.text.split(':')[0]
        last_name = name.split()[-1]
        first_name = name.split()[0]
        #names_of_prezs.append(name)
        #print('processed:',len(names_of_prezs),last_name)
    except:
        print('FAIL ON NAME:')
        
    title = last_name+'_'+first_name+'_'+date
    titles_speeches.append(title)
    print(title)
    
    #text
    speech_pars = []
    for p in soup.find('span', class_='displaytext').find_all('p'):
        speech_pars.append(p.get_text())
        
    text_of_speeches.append(str(speech_pars))
    print('PROCESSED:',len(text_of_speeches),'th SOTU')
    
    #write_out too
    f = open(title,'w')
    f.write(str(speech_pars))
    f.close()
# Out:
# Trump_Donald_February 28, 2017
# PROCESSED: 1 th SOTU
# Trump_Donald_January 30, 2018
# PROCESSED: 2 th SOTU
# Obama_Barack_February 12, 2013
# PROCESSED: 3 th SOTU
# Obama_Barack_January 28, 2014
# PROCESSED: 4 th SOTU
# Obama_Barack_January 20, 2015
# PROCESSED: 5 th SOTU
# Obama_Barack_January 12, 2016
# PROCESSED: 6 th SOTU
# Obama_Barack_February 24, 2009
# PROCESSED: 7 th SOTU
# Obama_Barack_January 27, 2010
# PROCESSED: 8 th SOTU
# Obama_Barack_January 25, 2011
# PROCESSED: 9 th SOTU
# Obama_Barack_January 24, 2012
# PROCESSED: 10 th SOTU
# Bush_George_February 2, 2005
# PROCESSED: 11 th SOTU
# Bush_George_January 31, 2006
# PROCESSED: 12 th SOTU
# Bush_George_January 23, 2007
# PROCESSED: 13 th SOTU
# Bush_George_January 28, 2008
# PROCESSED: 14 th SOTU
# Bush_George_February 27, 2001
# PROCESSED: 15 th SOTU
# Bush_George_January 29, 2002
# PROCESSED: 16 th SOTU
# Bush_George_January 28, 2003
# PROCESSED: 17 th SOTU
# Bush_George_January 20, 2004
# PROCESSED: 234 th SOTU
# Adams_John_December 3, 1799
# PROCESSED: 235 th SOTU
# Adams_John_November 11, 1800
# PROCESSED: 236 th SOTU
# Washington_George_December 3, 1793
# PROCESSED: 237 th SOTU
# Washington_George_November 19, 1794
# PROCESSED: 238 th SOTU
# Washington_George_December 8, 1795
# PROCESSED: 239 th SOTU
# Washington_George_December 7, 1796
# PROCESSED: 240 th SOTU
# Washington_George_January 8, 1790
# PROCESSED: 241 th SOTU
# Washington_George_December 8, 1790
# PROCESSED: 242 th SOTU
# Washington_George_October 25, 1791
# PROCESSED: 243 th SOTU
# Washington_George_November 6, 1792
# PROCESSED: 244 th SOTU

# %%
print(len(text_of_speeches)); print(len(titles_speeches))
# Out:
# 244
# 244

# %%
sotu_dict = dict(zip(titles_speeches,text_of_speeches))
pickle.dump(sotu_dict,open("sotu_dict.p","wb"))

# %% [markdown]
# ***
# ***
#
# <font color=darkgreen>
#
# ## Today:
#
# 1. How to use APIs
# 2. Twitter API examples: <br>
#     (a.) #metoo <br>
#     (b.) #maga <br>
#     (c.) @realDonaldTrump
# 3. Data storage options (JSON, CSV)
#
# ***

# %% [markdown]
# <font color=darkgreen>
#
# ### APIs
#
# - A set of protocols for two forms of software to communicate with one another.
# - Rather than loading a webpage and looking for content, APIs allow us to directly ask another machine for information.
# - Compared to web scraping, APIs are far more sane
# - Most major tech firms provide APIs
# - API  stands for 'application programming interface' and it is essentially a set of tools that allow you to communicate directly with a data server.
# - So, this means that all the little tricks we discussed last week (finding the right bit of HTML code, using a regex etc) are unnecessary
# - Moreover, since you are getting consistent streams of data, then you can save these data in a way that is human usable. Recall my warning last week: when scraping, you wish to have the smootest possible request->scrape->save code because if there is any little bump in the road, the whole program can crash.
#
# #### Stream vs REST API
#
# - Twitter has two types of APIs, one is the stream (a continuous unlimited flow of real time information), while the other is REST -- a repository which is one week old and is rate limited: 180 requests of up to 100 tweets per request every 15 minutes. (1200 tweets a minute)
# - Twitter is bad about providing historical data, but this is not true of other firms. If you want Twitter data, you'll have to let it run for a week.
#
# #### Lots of possible APIs:
# - Yelp
# - NYT
# - Wikipedia
# - JSTOR
# - Spotify
# - Open Movie Database
# - and many more!
#
# #### In general, here's what we'll do:
# 1. Go to the website in question, create a 'developer' account and be given a set of credentials.
# 2a. Go on Github and find the repository of the developer who wrote the API and look for a file like "sample.py" that provides an example way to access the API.
# 2b. Following 2a, install the developer  module and feed your credentials.
# 3. Make requests of the API for specific data you want. (Always include a delay so you don't get blocked!)
# 4. If there are restrictions on the API (can only access recent data or you have to pay for more), then we think through work-around.
#
#
#
# https://developer.twitter.com/en/docs
#
# https://apps.twitter.com/

# %% [markdown]
# <img src="twitter1.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="twitter2.png" alt="Drawing" style="width: 600px;"/>
#
# <img src="twitter3.png" alt="Drawing" style="width: 500px;"/>

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-3.5.0-py2.py3-none-any.whl
# Collecting requests-oauthlib>=0.4.1 (from tweepy)
#   Downloading requests_oauthlib-0.8.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.7.3 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from tweepy)
# Requirement already satisfied: requests>=2.4.3 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from tweepy)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.4.1->tweepy)
#   Downloading oauthlib-2.0.6.tar.gz (127kB)
#     100% |████████████████████████████████| 133kB 3.2MB/s ta 0:00:01
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: idna<2.7,>=2.5 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from requests>=2.4.3->tweepy)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zwehrwein/anaconda3/lib/python3.6/site-packages (from requests>=2.4.3->tweepy)
# Building wheels for collected packages: oauthlib
#   Running setup.py bdist_wheel for oauthlib ... done
#   Stored in directory: /Users/zwehrwein/Library/Caches/pip/wheels/e5/46/f7/bb2fde81726295a13a71e3c6396d362ab408921c6562d6efc0
# Successfully built oauthlib
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-2.0.6 requests-oauthlib-0.8.0 tweepy-3.5.0

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.18.0-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 2.9MB/s ta 0:00:01
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ***

# %% [markdown]
# <font color=darkgreen>
#
# ### PART1: Collect Tweets from the public 'garden house' using Twitter's own Python library.

# %%
from twitter import Twitter, OAuth, TwitterStream
import json #Twitter outputs data in JSON format, which we will save locally.

# %%
# API credentials
import tweepy
from tweepy import OAuthHandler


API_KEY = "GMCwaYz3FjycjSNamORMsfh6o"
API_SECRET = "b95joF79aiZfs9b1tSVUliCsJMwZJasBBklHQuSVjcyl3zWgs0"
ACCESS_TOKEN = "813490235099201536-mCd8VIMWdjpgVZh6D4SCIu9YdSjJ3D4"
ACCESS_SECRET = "6aBBdZEf6PnGPpLnXFVZT0Jlov3e9kJOQySCbB0ihrmq9"

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, API_KEY, API_SECRET)

# %%
# Connect to Twitter Stream API

twitter_stream = TwitterStream(auth=oauth)

# %%
# Get a sample of tweets

tweets_sample = twitter_stream.statuses.sample()

# %%
list_sample_tweets = list()
tweet_count = 100
for tweet in tweets_sample:
    
    # Count down from 0 to collect 1000 public tweets
    tweet_count -= 1
    
    print(tweet)
    list_sample_tweets.append(tweet)
    
    # Stop this loop once we hit 0.
    if tweet_count <= 0:
        break
# Out:
# {'delete': {'status': {'id': 660249530898731008, 'id_str': '660249530898731008', 'user_id': 1689671648, 'user_id_str': '1689671648'}, 'timestamp_ms': '1518122099344'}}
# {'created_at': 'Thu Feb 08 20:34:58 +0000 2018', 'id': 961699901355843584, 'id_str': '961699901355843584', 'text': '. @theadelaidesuk in Leeds Key Club 👌😍💞 https://t.co/fxNid88ndS', 'display_text_range': [0, 39], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20649632, 'id_str': '20649632', 'name': 'Taylor Fawn', 'screen_name': 'taylorfawn', 'location': 'UK', 'url': None, 'description': 'Social Media Customer Service Exec 💁🏻 Dog mum 🐕 Animal lover 💕 Love Supernatural, P!nk & F1 (Red Bull 🤞) 🤗', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 208, 'friends_count': 171, 'listed_count': 4, 'favourites_count': 208, 'statuses_count': 12530, 'created_at': 'Thu Feb 12 02:50:12 +0000 2009', 'utc_offset': 0, 'time_zone': 'London', 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/677278476/90e15d8d798437cec0be56b079c5e09b.gif', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/677278476/90e15d8d798437cec0be56b079c5e09b.gif', 'profile_background_tile': True, 'profile_link_color': 'F58EA8', 'profile_sidebar_border_color': '338929', 'profile_sidebar_fill_color': '6EC261', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/957712268950687744/IG2KLfAA_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/957712268950687744/IG2KLfAA_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20649632/1513752053', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'theadelaidesuk', 'name': 'The Adelaides', 'id': 887279189249970176, 'id_str': '887279189249970176', 'indices': [2, 17]}], 'symbols': [], 'media': [{'id': 961699800294068224, 'id_str': '961699800294068224', 'indices': [40, 63], 'media_url': 'http://pbs.twimg.com/media/DVik34EXkAAIrcO.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DVik34EXkAAIrcO.jpg', 'url': 'https://t.co/fxNid88ndS', 'display_url': 'pic.twitter.com/fxNid88ndS', 'expanded_url': 'https://twitter.com/taylorfawn/status/961699901355843584/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 961699800294068224, 'id_str': '961699800294068224', 'indices': [40, 63], 'media_url': 'http://pbs.twimg.com/media/DVik34EXkAAIrcO.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DVik34EXkAAIrcO.jpg', 'url': 'https://t.co/fxNid88ndS', 'display_url': 'pic.twitter.com/fxNid88ndS', 'expanded_url': 'https://twitter.com/taylorfawn/status/961699901355843584/photo/1', 'type': 'photo', 'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1518122098660'}
# {'delete': {'status': {'id': 926984586671861760, 'id_str': '926984586671861760', 'user_id': 18853454, 'user_id_str': '18853454'}, 'timestamp_ms': '1518122099527'}}
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905541681152, 'id_str': '961699905541681152', 'text': "RT @JeffLee2020: 'List of Soros' Names 226 MEPs in Europe Who Are Under the Complete Control of George Soros - https://t.co/oo05OgK3WN  @ca…", 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1425348680, 'id_str': '1425348680', 'name': 'Soley Nikita Botski Liberté', 'screen_name': 'Soleyliberte', 'location': 'Behind the lens', 'url': None, 'description': 'Country Bumpkin fuse loighter extraordinaire, Ailurophile,Artisan,Photographer,Libertarian,RT are not endorsements.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1479, 'friends_count': 1692, 'listed_count': 126, 'favourites_count': 17570, 'statuses_count': 3259, 'created_at': 'Mon May 13 11:58:53 +0000 2013', 'utc_offset': 0, 'time_zone': 'London', 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '94D487', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/658643929739448321/ge6mV4j0.jpg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/658643929739448321/ge6mV4j0.jpg', 'profile_background_tile': True, 'profile_link_color': 'AABB33', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/953642149861609473/EDoZO3kj_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/953642149861609473/EDoZO3kj_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1425348680/1518106360', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Nov 09 23:01:09 +0000 2017', 'id': 928759393864310784, 'id_str': '928759393864310784', 'text': "'List of Soros' Names 226 MEPs in Europe Who Are Under the Complete Control of George Soros -… https://t.co/rZRjc4gkMM", 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 86796377, 'id_str': '86796377', 'name': 'Jeff  Lee', 'screen_name': 'JeffLee2020', 'location': 'United States', 'url': None, 'description': "I'm christian; veteran~patriot & contractor 15+yrs USN. Idea parties is wrong. I love ALL USA PEOPLE & we need focus on specific issues & stop name calling.USA!", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3293, 'friends_count': 932, 'listed_count': 370, 'favourites_count': 74323, 'statuses_count': 271161, 'created_at': 'Sun Nov 01 20:33:58 +0000 2009', 'utc_offset': -18000, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'A1F5EE', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/498588587424624640/7gOBXnop.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/498588587424624640/7gOBXnop.jpeg', 'profile_background_tile': True, 'profile_link_color': '1B95E0', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDFFCC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/933132043122 ...
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905571053570, 'id_str': '961699905571053570', 'text': 'Is today Make-A-Typo day? Lmao', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 883186321359081472, 'id_str': '883186321359081472', 'name': 'cyndy', 'screen_name': 'cywxz', 'location': 'Dallas, TX', 'url': None, 'description': 'QUACK QUACK MUDAFUKKA', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 77, 'friends_count': 70, 'listed_count': 0, 'favourites_count': 1068, 'statuses_count': 1256, 'created_at': 'Fri Jul 07 04:50:02 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/959207159555911680/oF9LbP7d_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/959207159555911680/oF9LbP7d_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/883186321359081472/1515773723', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '18810aa5b43e76c7', 'url': 'https://api.twitter.com/1.1/geo/id/18810aa5b43e76c7.json', 'place_type': 'city', 'name': 'Dallas', 'full_name': 'Dallas, TX', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-96.977527, 32.620678], [-96.977527, 33.019039], [-96.54598, 33.019039], [-96.54598, 32.620678]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1518122099665'}
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905562701824, 'id_str': '961699905562701824', 'text': 'I’m done doing over time i swear😢😢', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 760620457, 'id_str': '760620457', 'name': 'URFAVMILF', 'screen_name': 'celestemarlen_', 'location': 'Houston, TX', 'url': None, 'description': 'MADS 💗', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1060, 'friends_count': 164, 'listed_count': 9, 'favourites_count': 41570, 'statuses_count': 65751, 'created_at': 'Thu Aug 16 02:18:43 +0000 2012', 'utc_offset': -36000, 'time_zone': 'Hawaii', 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '51C0F7', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000060844663/b50b8805fe12e569f5cc5c882facc624.gif', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000060844663/b50b8805fe12e569f5cc5c882facc624.gif', 'profile_background_tile': True, 'profile_link_color': 'F58EA8', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/958279340298514432/MDwjMtoS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958279340298514432/MDwjMtoS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/760620457/1517306785', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1518122099663'}
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905566855174, 'id_str': '961699905566855174', 'text': 'RT @letat_lechat: @BeverleeHughes3 @HillaryClinton Hillary Clinton won the 2016 election. Trump was installed by Putin and is not the legit…', 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 364601868, 'id_str': '364601868', 'name': 'JerseyStrong11🍩', 'screen_name': 'JerseyStrong11', 'location': 'Philadelphia', 'url': None, 'description': 'Jersey Girl! #Feminist. HRC is the rightful 45th POTUS #ImStillWithHer #StolenElection #TheResistance             I❤my German Shorthair Pointer! 🇺🇸🇮🇹🏳️\u200d🌈', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1102, 'friends_count': 520, 'listed_count': 59, 'favourites_count': 102608, 'statuses_count': 90045, 'created_at': 'Tue Aug 30 01:11:53 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/822237495966466048/07PmqOGV_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822237495966466048/07PmqOGV_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/364601868/1478730444', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 08 20:16:56 +0000 2018', 'id': 961695361864581121, 'id_str': '961695361864581121', 'text': '@BeverleeHughes3 @HillaryClinton Hillary Clinton won the 2016 election. Trump was installed by Putin and is not the… https://t.co/7zbhqIdr44', 'display_text_range': [33, 140], 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>', 'truncated': True, 'in_reply_to_status_id': 961685897770164226, 'in_reply_to_status_id_str': '961685897770164226', 'in_reply_to_user_id': 2434294310, 'in_reply_to_user_id_str': '2434294310', 'in_reply_to_screen_name': 'BeverleeHughes3', 'user': {'id': 275714700, 'id_str': '275714700', 'name': "(((L'EtatC'estMoi)))", 'screen_name': 'letat_lechat', 'location': None, 'url': None, 'description': "Feminist. Liberal. Voter. | Don't agonize, ORGANIZE. - Flo Kennedy | Resist, insist, persist, enlist | Our human rights and nothing less. #ProChoice #Resistance", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 13771, 'friends_count': 14480, 'listed_count': 413, 'favourites_count': 35912, 'statuses_count': 243824, 'created_at': 'Fri Apr 01 21:10:03 +0000 2011', 'utc_offset': -21600, 'time_zone': 'Central Time (US & Canada)', 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'ADD3DE', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '038543', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'F6F6F6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/84000 ...
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905545781248, 'id_str': '961699905545781248', 'text': 'RT @jidan_no_jouken: 一\n十\n百\n千\n万\n億\n兆\n京\n垓\n杼\n穣\n溝\n澗\n正\n載\n疲\n不幸\n黒塗\n高級車\n追突\n後輩庇\n全責任\n負三浦\n対車主\n暴力団員谷岡\n言渡示談之条件', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 796775747100643328, 'id_str': '796775747100643328', 'name': 'ちべん', 'screen_name': 'chiben_620', 'location': 'コジョンドの巣', 'url': 'http://chibenpoke.hatenablog.com', 'description': '†コジョンド愛† 育成済みコジョンド数68 USUMコジョンド入り最高2046(S7) TN:ちべンゴ/テデザ❤︎リゼ ちな虎 長年にわたってキヨシのアイコンを担当', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 712, 'friends_count': 720, 'listed_count': 7, 'favourites_count': 1152, 'statuses_count': 3638, 'created_at': 'Thu Nov 10 18:05:16 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'ja', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/943549524219326465/PPFtkJKc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/943549524219326465/PPFtkJKc_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/796775747100643328/1517165323', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 08 20:32:02 +0000 2018', 'id': 961699164085104640, 'id_str': '961699164085104640', 'text': '一\n十\n百\n千\n万\n億\n兆\n京\n垓\n杼\n穣\n溝\n澗\n正\n載\n疲\n不幸\n黒塗\n高級車\n追突\n後輩庇\n全責任\n負三浦\n対車主\n暴力団員谷岡\n言渡示談之条件', 'source': '<a href="https://twitter.com/jidan_no_jouken" rel="nofollow">下北沢の路上</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2569492147, 'id_str': '2569492147', 'name': '黒塗りの高級車に追突してしまうbot', 'screen_name': 'jidan_no_jouken', 'location': '下北沢', 'url': None, 'description': '試合を終えて家路へ向かうサッカー部員達。疲れからか、不幸にも黒塗りの高級車に追突してしまう。後輩をかばいすべての責任を負った三浦に対し、車の主、暴力団員谷岡に言い渡された示談の条件とは…。', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 125684, 'friends_count': 1, 'listed_count': 1496, 'favourites_count': 1, 'statuses_count': 13457, 'created_at': 'Sun Jun 15 18:46:10 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'ja', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/498748430911410176/Gjwgg1v1.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/498748430911410176/Gjwgg1v1.jpeg', 'profile_background_tile': True, 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/948541011143225344/jti-3oOa_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/948541011143225344/jti-3oOa_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2569492147/1402858519', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None,  ...
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905575247873, 'id_str': '961699905575247873', 'text': 'RT @vamoarribagusc: Los que falta son tato y angelaaa \nSIMONA EN PASAPALABRA', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 945433778402529281, 'id_str': '945433778402529281', 'name': 'Giulii 🏹', 'screen_name': 'AgusftCastondar', 'location': None, 'url': None, 'description': 'Argentina como Messi❤ De River hasta la muerte ~ 1/01/18 Agustin me dio fav 1/01/17 Mariano me dio fav😍❤~  MB AC LC LM❤', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count':
 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 56863, 'friends_count': 6975, 'listed_count': 170, 'favourites_count': 186317, 'statuses_count': 207746, 'created_at': 'Wed Apr 12 15:47:43 +0000 2017', 'utc_offset': 3600, 'time_zone': 'Berlin', 'geo_enabled': False, 'lang': 'de', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/937263905470115845/OP-sAWNr_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/937263905470115845/OP-sAWNr_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': ...
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905566887936, 'id_str': '961699905566887936', 'text': "RT @jnflesch: Grupo de kpop que vem no primeiro semestre está com vídeo com um 'hi Brazil' prontinho pra soltar. Já pode falar quem é, entã…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3324067383, 'id_str': '3324067383', 'name': 'XoXo🐰', 'screen_name': 'BTSalways_', 'location': 'Lugar  bem longe da Coreia ', 'url': None, 'description': 'é preciso ter o caos dentro de si, para suportar uma estrela brilhante', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 423, 'friends_count': 914, 'listed_count': 2, 'favourites_count': 11954, 'statuses_count': 12255, 'created_at': 'Sun Jun 14 03:04:19 +0000 2015', 'utc_offset': -28800, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'lang': 'pt', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/958468089833811968/q4WM9hRs_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/958468089833811968/q4WM9hRs_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3324067383/1517715081', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 08 17:46:22 +0000 2018', 'id': 961657471357128704, 'id_str': '961657471357128704', 'text': "Grupo de kpop que vem no primeiro semestre está com vídeo com um 'hi Brazil' prontinho pra soltar. Já pode falar qu… https://t.co/PmNQkJ1WoP", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 26426132, 'id_str': '26426132', 'name': 'José Norberto Flesch', 'screen_name': 'jnflesch', 'location': 'Brazil', 'url': 'http://facebook.com/josenorbertoflesch', 'description': 'Editor de Diversão & Arte do @destak', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 264371, 'friends_count': 578, 'listed_count': 924, 'favourites_count': 2147, 'statuses_count': 131034, 'created_at': 'Wed Mar 25 04:05:34 +0000 2009', 'utc_offset': -7200, 'time_zone': 'Brasilia', 'geo_enabled': True, 'lang': 'pt', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/899335427001380864/WblXpeEy_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/899335427001380864/WblXpeEy_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notificati ...
# {'created_at': 'Thu Feb 08 20:34:59 +0000 2018', 'id': 961699905571098624, 'id_str': '961699905571098624', 'text': '@reggiewatts This rips. I listen to it once every two weeks for inspiration.', 'display_text_range': [13, 76], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>', 'truncated': False, 'in_reply_to_status_id': 961664179340951553, 'in_reply_to_status_id_str': '961664179340951553', 'in_reply_to_user_id': 14133970, 'in_reply_to_user_id_str': '14133970', 'in_reply_to_screen_name': 'reggiewatts', 'user': {'id': 1877946656, 'id_str': '1877946656', 'name': 'Cory Frontin', 'screen_name': 'wild34bill', 'location': 'Cambridge, MA', 'url': None, 'description': 'DeMatha Stag. Maryland Terrapin, Boston Tech Engineer. Avid enthusiast of the Baltimore Orioles, specializing in aerospace engineering.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 93, 'friends_count': 259, 'listed_count': 2, 'favourites_count': 391, 'statuses_count': 265, 'created_at': 'Wed Sep 18 03:53:21 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'FB4F14', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000472493390/ca87a66715c01c84e1e64b28b5f09ec8_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000472493390/ca87a66715c01c84e1e64b28b5f09ec8_normal.jpeg', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'reggiewatts', 'name': 'reggie watts', 'id': 14133970, 'id_str': '14133970', 'indices': [0, 12]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '
_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/951897234123223041/mv47Y-wZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/708709917931208704/1463848756', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 08 14:04:08 +0000 2018', 'id': 961601543345725441, 'id_str': '961601543345725441', 'text': 'Mano na real n tem decepção maior do q olhar p alguém q vc achava q era incrível e perceber q a pessoa na verdade é um lixo.', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 276527395, 'id_str': '276527395', 'name': 'Bad neves', 'screen_name': 'luucasneves_', 'location': 'maringá-pr', 'url': 'http://instagram.com/lucasnevees__/', 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 3696, 'friends_count': 1803, 'listed_count': 28, 'favourites_count': 75811, 'statuses_count': 163136, 'created_at': 'Sun Apr 03 14:59:59 +0000 2011', 'utc_offset': -7200, 'time_zone': 'Brasilia', 'geo_enabled': True, 'lang': 'pt', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '121212', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/649247676085747712/IWQLsl6q.jpg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/649247676085747712/IWQLsl6q.jpg', 'profile_background_tile': True, 'profile_link_color': '17CCE8', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/961415746902470656/Epxhcln4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/961415746902470656/Epxhcln4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/276527395/1485552739', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifica ...

# %%
type(list_sample_tweets[5])

# Designed to function like a dictionary object.
# Out:
# twitter.api.TwitterDictResponse

# %% [markdown]
# <font color=darkgreen>
#
# - text: the text of the actual tweet;
# - created_at: the date of creation;
# - favorite_count: the number of favorites of this tweet;
# - retweet_count: the number of retweets;
# - lang: the language of the tweet;
# - id: the tweet identifier;
# - place: geo-location information;
# - user: the profile of the author of the tweet.

# %%
list_sample_tweets[60]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Feb 08 20:35:00 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 961699909748453376,
#  'id_str': '961699909748453376',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'is',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://bit.ly/aIDZ9L" rel="nofollow">oizumix</a>',
#  'text': 'Fri, 09 Feb 2018 05:35:00 +0900',
#  'timestamp_ms': '1518122100661',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Apr 03 09:49:49 +0000 2010',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '遅延測定中',
#   'favourites_count': 0,
#   'follow_request_sent': None,
#   'followers_count': 33,
#   'following': None,
#   'friends_count': 8,
#   'geo_enabled': False,
#   'id': 129149414,
#   'id_str': '129149414',
#   'is_translator': False,
#   'lang': 'ja',
#   'listed_count': 1,
#   'location': '練馬のIDC',
#   'name': 'テストで',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/129149414/1400948757',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/470248497258582016/YWvQRLUG_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/470248497258582016/YWvQRLUG_normal.png',
#   'profile_link_color': '051196',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'oizumix',
#   'statuses_count': 833965,
#   'time_zone': 'Tokyo',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': 32400,
#   'verified': False}}

# %%
list_sample_tweets[78]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Feb 08 20:35:00 +0000 2018',
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [{'indices': [0, 7], 'text': 'fraaie'},
#    {'indices': [8, 13], 'text': 'date'},
#    {'indices': [18, 23], 'text': 'Sexy'},
#    {'indices': [94, 103], 'text': 'sensueel'}],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/9…',
#     'expanded_url': 'https://twitter.com/i/web/status/961699909752819718',
#     'indices': [121, 144],
#     'url': 'https://t.co/s1M88KYcQ6'}],
#   'user_mentions': []},
#  'extended_tweet': {'display_text_range': [0, 233],
#   'entities': {'hashtags': [{'indices': [0, 7], 'text': 'fraaie'},
#     {'indices': [8, 13], 'text': 'date'},
#     {'indices': [18, 23], 'text': 'Sexy'},
#     {'indices': [94, 103], 'text': 'sensueel'},
#     {'indices': [197, 206], 'text': 'genieten'}],
#    'media': [{'display_url': 'pic.twitter.com/eKWXRyJVVr',
#      'expanded_url': 'https://twitter.com/webcamsex2_0/status/961699909752819718/photo/1',
#      'id': 961332534696128512,
#      'id_str': '961332534696128512',
#      'indices': [234, 257],
#      'media_url': 'http://pbs.twimg.com/media/DVdW2NGWsAA4nPc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DVdW2NGWsAA4nPc.jpg',
#      'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 800},
#       'medium': {'h': 600, 'resize': 'fit', 'w': 800},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/eKWXRyJVVr'}],
#    'symbols': [],
#    'urls': [{'display_url': 'camsexxx.nl/profiel/sexyka…',
#      'expanded_url': 'http://camsexxx.nl/profiel/sexykathie/?p=1011190&pi=camsexxx.nl',
#      'indices': [210, 233],
#      'url': 'https://t.co/FA9pTdofkM'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/eKWXRyJVVr',
#      'expanded_url': 'https://twitter.com/webcamsex2_0/status/961699909752819718/photo/1',
#      'id': 961332534696128512,
#      'id_str': '961332534696128512',
#      'indices': [234, 257],
#      'media_url': 'http://pbs.twimg.com/media/DVdW2NGWsAA4nPc.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DVdW2NGWsAA4nPc.jpg',
#      'sizes': {'large': {'h': 600, 'resize': 'fit', 'w': 800},
#       'medium': {'h': 600, 'resize': 'fit', 'w': 800},
#       'small': {'h': 510, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/eKWXRyJVVr'}]},
#   'full_text': '#fraaie #date met #Sexy kathie (24)\nHey boef, leuk dat je een kijkje komt nemen. Ik ben lief, #sensueel &amp; openhartig.  Heb ik je nieuwsgierig gemaakt wil je meer weten? Kom gezellig kletsen en #genieten ;) https://t.co/FA9pTdofkM https://t.co/eKWXRyJVVr'},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 961699909752819718,
#  'id_str': '961699909752819718',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'nl',
#  'place': None,
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#  'text': '#fraaie #date met #Sexy kathie (24)\nHey boef, leuk dat je een kijkje komt nemen. Ik ben lief, #sensueel &amp; openharti… https://t.co/s1M88KYcQ6',
#  'timestamp_ms': '1518122100662',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Dec 16 16:52:37 +0000 2016',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Lekker webcammen en geilen met webcambabes en shemales http://www.camsexxx.nl/?pi=twitprofile dating is mogelijk',
#   'favourites_count': 14,
#   'follow_request_sent': None,
#   'followers_count': 2082,
#   'following': None,
#   'friends_count': 4845,
#   'geo_enabled': False,
#   'id': 809803427668705281,
#   'id_str': '809803427668705281',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 29,
#   'location': None,
#   'name': 'webcamsex',
#   'notifications': None,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/809803427668705281/1502916290',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/815967859952275456/_TzRzcgG_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815967859952275456/_TzRzcgG_normal.jpg',
#   'profile_link_color': '981CEB',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'webcamsex2_0',
#   'statuses_count': 69879,
#   'time_zone': 'Pacific Time (US & Canada)',
#   'translator_type': 'none',
#   'url': 'http://camsexxx.nl/',
#   'utc_offset': -28800,
#   'verified': False}}

# %% [markdown]
# <font color=darkgreen>
#
# **This isn't that interesting though:**
#
# - Single hashtag?
# - Keep it local?
#
# Again, consult the docs:
#
# https://twitterapi.readthedocs.io/en/latest/
#
# https://developer.twitter.com/en/docs
#
# https://github.com/sixohsix/twitter
#
# https://github.com/ideoforms/python-twitter-examples

# %%
metoo_tweets_list = list()

tweet_count = 10
#call the twitter stream, then the statuses method to then filter
for tweet in twitter_stream.statuses.filter(track='#metoo',language='en'):
    
    # Count down from 0 to collect 1000 public tweets
    tweet_count -= 1
    
    
    #print text of tweet to see what it says
    print(tweet['text'])
    
    #save data out
    metoo_tweets_list.append(tweet)
    #json.dumps(metoo_tweets_list)
    
    json_doc = json.dumps(metoo_tweets_list)
    #outputFile.write(json_doc.encode('utf8') + '\n')
    
    #open up a json file, call it metoo tweets, write to it
    out_json = open('metoo_tweets.json','w')
    out_json.write(json_doc)
    out_json.close()
    
    # Stop this loop once we hit 0.
    if tweet_count <= 0:
        break
# Out:
# RT @joncoopertweets: "Nicole [Eggert] answered all of their questions for over an hour and told her story of sexual abuse by Scott Baio whe…
# RT @CRTV: Every woman needs to watch this.
# @ConservMillen chats w/ #2A champion @TheAmyRobbins from @AlexoAthletica, a concealed-carry focu…
# RT @CanosaGabriella: Criticise with no evidence, reply with only insults, doesn't make you smart.
# Ignorance has so many followers nowadays…
# RT @monaeltahawy: In 2013, I was 1st person to talk about being sexually assaulted at Haj on Arabic-language #Egyptian primetime TV show. I…
# RT @SophiaBush: This is how cultures of abuse are built, in all industries. Wonder why women have suffered in silence for so long, creating…
# RT @sassysanborn: We can't romanticize the same things we rally against. We can't have it both ways. 'There's No Room for "Fifty Shades" in…
# RT @perkinsmiki: Kudos to the brave women and @withMEAA members who have made allegations of a dangerous, misogynistic workplace at Soverei…
# #ThursdayThoughts
# I wish @MikaBrezinski would do this with Hillary Clinton.
# Standing up for #MeToo
# #TimesUp
# Thanks… https://t.co/h745Td2tCq
# RT @TheAdvocateMag: Is it a coincidence that #ScottBaio is a #Trump supporter? #MeToo https://t.co/sFtuU1nw3h
# RT @LRN: #ICYMI: Here are excerpts from Dr. Marsha Ershaghi Hames @ZappyLibra appearance on a podcast with @tfoxlaw, about having difficult…

# %%
len(metoo_tweets_list)
# Out:
# 10

# %%
maga_tweets_list = list()

tweet_count = 10
#call the twitter stream, then the statuses method to then filter
for tweet in twitter_stream.statuses.filter(track='#maga',language='en'):
    
    # Count down from 0 to collect 1000 public tweets
    tweet_count -= 1
    
    
    #print text of tweet to see what it says
    print(tweet['text'])
    
    #save data out
    maga_tweets_list.append(tweet)
    #json.dumps(metoo_tweets_list)
    
    json_doc = json.dumps(maga_tweets_list)
    #outputFile.write(json_doc.encode('utf8') + '\n')
    
    #open up a json file, call it metoo tweets, write to it
    out_json = open('maga_tweets.json','w')
    out_json.write(json_doc)
    out_json.close()
    
    # Stop this loop once we hit 0.
    if tweet_count <= 0:
        break
# Out:
# RT @PatriotLexi: 📍 Angel Mom Laura Wilkerson Commented on House Democratic Leader @NancyPelosi's Defense of DREAMers
#
# We Wish She Would Do…
# RT @CoreyLMJones: 🇺🇸WINNING!🇺🇸
# “One of the most reliable national pollsters, Rasmussen, currently shows Trump as having surpassed Pres. Oba…
# RT @GartrellLinda: #MAGA: Mexico Loses Chrysler Car Plant and 2500 Jobs to Americans in 2020
# Fiat is investing over $1 BILLION on their Ram…
# RT @LouDobbs: Deep State Corruption- @GreggJarrett: The credibility and trust of the FBI has been ruined by Comey, McCabe, Strzok, Rybicki,…
# RT @ClintonM614: Yesterday Nancy Pelosi stood for 8 hours demanding rights for illegal aliens but couldn't stand for 30 seconds during the…
# RT @JimmyChanda4: An aging overweight Northwestern Professor Barry Bluestone, told his students, "I wouldn't mind seeing Trump dead."
#
# How…
# RT @NokesMR: Keep the Trump train rolling, #WootWoot!  #MAGA
# @GeorgiaDirtRoad
# @APTT45Babe
# @jimlibertarian
# @SharonLesley11
# @LisaMei62
# @J…
# RT @ericbolling: A couple of great conservative “must follows”
# @Lrihendry
# @KamVTV
#
# #maga.
# RT @SaarioBrandon: If there is 1 person we need in Congress it's AJ.  #CaliforniaBold #MAGA https://t.co/2aXK2nfyI6
# RT @RNRKentucky: Faith Hill:  🇺🇸❤️"American Heart"❤️🇺🇸
# This song describes my❤️for America. 'A pride inside you can't burn out'.
# Keep the…

# %%
len(metoo_tweets_list)
# Out:
# 10

# %% [markdown]
# <font color=darkgreen>
#
# ### JSON files
#
# - Use the new Firefox browser to open JSON files
# - out of Python structured as a dictionary (that is, key-value pairs)
# - json_x.load() will load the json object 'json_x' as a dictionary in Py
# - Because they are saved locally, this requires some code to tell the computer what to save
#
#
# `JSON_DUMP = json.dumps(ENTITY)` This takes a Python objects and puts into a json object that is now held in memory. <br>
# `LOCAL_FILE_NAME = open('LOCAL_FILE_NAME'.json, 'w')` 'w' means 'write to file'; this opens a local file. <br>
# `LOCAL_FILE_NAME.write(JSON_DUMP)` Take that json object you have in memory and write it to the local file. <br>
# `LOCAL_FILE_NAME.close()` Close and save local file. n.b. the json object is still held in memory at this point, but it's also out of the Python program. <br>
#
# Likewise, to open up a local file, do this: <br>
# `
# with open("LOCAL_FILE_NAME.json") as JSON_FILE:
#     back_to_py = json.load(JSON_FILE)`

# %% [markdown]
# ***

# %% [markdown]
# <font color=darkgreen>
#
# ### PART2: For more detailed searches (beyond just the stream), we'll turn to a wrapper around the Twitter API called tweepy
#
# https://github.com/tweepy/tweepy
#
# Docs: https://media.readthedocs.org/pdf/tweepy/v3.2.0/tweepy.pdf
#
# **n.b tweepy returns a different type of object compared to the Twitter api -- a 'status' object which functions a bit differently -- always important to read the docs**

# %%
import tweepy
from tweepy import OAuthHandler

# %%
#AUTHENTICATE

auth = OAuthHandler(API_KEY,API_SECRET)
auth.set_access_token(ACCESS_TOKEN,ACCESS_SECRET)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %% [markdown]
# <font color=darkgreen>
#
# * `wait_on_rate_limit=True` means that tweepy will exhaust the amount of 'calls' you can make to the API and wait for a refresh. In order to avoid being overwhelmed, most APIs specify a certain number of calls per hour (always check their documentation).
#
# Full tweepy docs:
#
# http://docs.tweepy.org/en/v3.5.0/getting_started.html
#
#
# https://media.readthedocs.org/pdf/tweepy/latest/tweepy.pdf
#
# Best tweepy practices:
#
# http://www.nirg.net/using-tweepy.html
#
# ***

# %%
# CHECK STATUS IS AN OPTION WITH tweepy
print(api.me().name)
# Out:
# zachwehrwein

# %% [markdown]
# <font color=darkgreen>
#
# ## CSV files
#
# - 'comma seperated values'
# - flexible and useful for almost all dataframe like analyses
# - Not widely used because we're creating a data structure perhaps before we've really thought about it (flat frame)
# - You have to specify which bits of data that you wish.
#
# For 'status' objects created by tweepy, these are the following:
#
# * 'author',
# * 'contributors',
# * 'coordinates',
# * 'created_at',
# * 'destroy',
# * 'entities',
# * 'extended_entities',
# * 'favorite',
# * 'favorite_count',
# * 'favorited',
# * 'geo',
# * 'id',
# * 'id_str',
# * 'in_reply_to_screen_name',
# * 'in_reply_to_status_id',
# * 'in_reply_to_status_id_str',
# * 'in_reply_to_user_id',
# * 'in_reply_to_user_id_str',
# * 'is_quote_status',
# * 'lang',
# * 'metadata',
# * 'parse',
# * 'parse_list',
# * 'place',
# * 'possibly_sensitive',
# * 'retweet',
# * 'retweet_count',
# * 'retweeted',
# * 'retweets',
# * 'source',
# * 'source_url',
# * 'text',
# * 'truncated',
# * 'user'

# %% [raw]
# ## CODE DOESN'T ITERATE ##
#
# import csv
#
# # again you're creating a variable which links to a local file
# file = open('tweets_csv.csv', 'a')
#
# # open
# writer = csv.writer(file)
#
# tweet_count = 100
#
# while tweet_count > 0:
#     for tweet in tweepy.Cursor(api.search, q="shithole", language='en').items(10):
#         tweet_count -= 1
#
#         writer.writerow([tweet.created_at, tweet.text.encode('utf-8')])
#         print(tweet.created_at, tweet.text)
#
#         #the file itself, not the writer is closed.
#
#         if tweet_count <= 0:
#             break
#
# file.close()

# %% [markdown]
# <font color=darkgreen>
#
# ### PART3: getting a handle on the current status of American foreign policy (i.e. downloading @realDonaldTrump's timeline)

# %%
import csv
import time

all_trump_tweets = list()
all_trump_file = open('all_trump_tweets.csv', 'a')
all_trump_writer = csv.writer(all_trump_file)

#initial request
new_trump_tweets = api.user_timeline(screen_name='realDonaldTrump',count=200)
all_trump_tweets.extend(new_trump_tweets)
oldest_tweet = all_trump_tweets[-1].id - 1
oldest_created_at = all_trump_tweets[-1].created_at

while len(new_trump_tweets) > 0:
    print('Getting a new round of Trump tweets starting from:', oldest_created_at)
    
    new_trump_tweets = api.user_timeline(screen_name='realDonaldTrump',count=200,max_id=oldest_tweet)
    
    all_trump_tweets.extend(new_trump_tweets)
    
    #write out

    for tweet in new_trump_tweets:
        out_data = [tweet.created_at,
                    tweet.favorite_count,
                    tweet.in_reply_to_screen_name,
                    tweet.retweet_count,
                    tweet.source,
                    tweet.text.encode("utf-8")]
    
        all_trump_writer.writerow(out_data)
    
    oldest_tweet = all_trump_tweets[-1].id - 1
    oldest_created_at = all_trump_tweets[-1].created_at
    
    time.sleep(60)
    
    print('\n',len(all_trump_tweets),'Trump tweets have been collected so far.','\n')
    
    
all_trump_file.close()
# Out:
# Getting a new round of Trump tweets starting from: 2018-01-07 14:33:10
#
#  400 Trump tweets have been collected so far.
#
# Getting a new round of Trump tweets starting from: 2017-12-07 13:03:00
#
#  597 Trump tweets have been collected so far.
#
# Getting a new round of Trump tweets starting from: 2017-11-09 23:44:17
#
#  797 Trump tweets have been collected so far.
#
# Getting a new round of Trump tweets starting from: 2017-10-20 10:31:50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-fe08d92b3920> in <module>()
#      34     oldest_created_at = all_trump_tweets[-1].created_at
#      35
# ---> 36     time.sleep(60)
#      37
#      38     print('\n',len(all_trump_tweets),'Trump tweets have been collected so far.','\n')
#
# KeyboardInterrupt:

# %% [markdown]
# <font color=darkred>
#
# ### Our file is about 35,000 tweets short of getting the whole corpus -- what could we do?
#
# <br>
# <br>
# <br>
#
# -- Include delays? <br>
# -- Call a larger iteration <br>
# -- Change the dates for 'oldest' tweet? <br>
# -- Except / Pass error messages. <br>
# -- Does tweepy have a function to let you see your current call status? Could we build something off that? <br>
# -- You could just keep running that cell over and over again... but why?
#
# ***

# %%
api = tweepy.API(auth)

# %%
api.rate_limit_status()['resources']['users']

# %%
all_trump_tweets = list()
all_trump_file = open('all_trump_tweets.csv', 'a')
all_trump_writer = csv.writer(all_trump_file)

#initial request
new_trump_tweets = api.user_timeline(screen_name='realDonaldTrump',count=200)
all_trump_tweets.extend(new_trump_tweets)
oldest_tweet = all_trump_tweets[-1].id - 1
oldest_created_at = all_trump_tweets[-1].created_at

while len(new_trump_tweets) > 0:
    print('Getting a new round of Trump tweets starting from:', oldest_created_at)
    
    new_trump_tweets = api.user_timeline(screen_name='realDonaldTrump',count=200,max_id=oldest_tweet)
    
    all_trump_tweets.extend(new_trump_tweets)
    
    #write out

    for tweet in new_trump_tweets:
        out_data = [tweet.created_at,
                    tweet.favorite_count,
                    tweet.in_reply_to_screen_name,
                    tweet.retweet_count,
                    tweet.source,
                    tweet.text.encode("utf-8")]
    
        all_trump_writer.writerow(out_data)
    
    oldest_tweet = all_trump_tweets[-1].id - 1
    oldest_created_at = all_trump_tweets[-1].created_at
    
    ### INCLUDE A TIME DELAY###
    time.sleep(60)
    
    print('\n',len(all_trump_tweets),'Trump tweets have been collected so far.','\n')
    
    
all_trump_file.close()

# %% [markdown]
# <font color=darkgreen>
#
# ### Use the RCE
#
# https://rce-docs.hmdc.harvard.edu/book/accessing-rce-0

# %% [markdown]
# <font color=darkred>
#
# ## Exercise :
#
# #### Who does Donald Trump read? Can you write a simple Python scrip to detect when the nuke's gonna fly?
#
# In other words, can you recreate Trump's feed in a CSV? Itterate through a list of his friends and call the 5 most recent tweets and save this to a CSV file. Then sort either in a notebook or in the CSV file itself by date to recreate his actual feed.

# %%
trump_friends = []
for friend in api.get_user('realDonaldTrump').friends(count=50):
    trump_friends.append(friend.screen_name)

# %%
trump_friends
# Out:
# ['PressSec',
#  'TuckerCarlson',
#  'JesseBWatters',
#  'WhiteHouse',
#  'Scavino45',
#  'KellyannePolls',
#  'Reince',
#  'RealRomaDowney',
#  'Trump',
#  'TrumpGolf',
#  'TiffanyATrump',
#  'IngrahamAngle',
#  'mike_pence',
#  'TeamTrump',
#  'DRUDGE_REPORT',
#  'MrsVanessaTrump',
#  'LaraLeaTrump',
#  'seanhannity',
#  'foxnation',
#  'CLewandowski_',
#  'AnnCoulter',
#  'DiamondandSilk',
#  'KatrinaCampins',
#  'KatrinaPierson',
#  'MichaelCohen212',
#  'foxandfriends',
#  'MELANIATRUMP',
#  'GeraldoRivera',
#  'ericbolling',
#  'MarkBurnettTV',
#  'garyplayer',
#  'VinceMcMahon',
#  'DanScavino',
#  'TrumpDoral',
#  'TrumpCharlotte',
#  'TrumpLasVegas',
#  'TrumpChicago',
#  'TrumpGolfDC',
#  'TrumpGolfLA',
#  'EricTrump',
#  'BillOReilly',
#  'greta',
#  'piersmorgan',
#  'DonaldJTrumpJr',
#  'IvankaTrump']

# %% [markdown]
# <font color=green>
#
# # TO RECAP:
#
# * **APIs are better than scrapping HTML / XML**
# * **There are data restriction limits however these will be app specific. For instance, Spotify will only give you named Playlists, so you have to find a way to get a large list of playlist names. With Twitter, telling the computer to keep trying after it has hit its limit.**
# * **Look to Github and docs for examples.**

# %% [markdown]
# # SOLUTIONS:

# %%
import tweepy
from tweepy import OAuthHandler


API_KEY = "GMCwaYz3FjycjSNamORMsfh6o"
API_SECRET = "b95joF79aiZfs9b1tSVUliCsJMwZJasBBklHQuSVjcyl3zWgs0"
ACCESS_TOKEN = "813490235099201536-mCd8VIMWdjpgVZh6D4SCIu9YdSjJ3D4"
ACCESS_SECRET = "6aBBdZEf6PnGPpLnXFVZT0Jlov3e9kJOQySCbB0ihrmq9"

# %%
auth = OAuthHandler(API_KEY,API_SECRET)
auth.set_access_token(ACCESS_TOKEN,ACCESS_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

trump_friends = []
for friend in api.get_user('realDonaldTrump').friends(count=50):
    trump_friends.append(friend.screen_name)

# %%
trump_friends = []
for friend in api.get_user('realDonaldTrump').friends():
    trump_friends.append(friend.screen_name)

# %%
trump_friends
# Out:
# ['PressSec',
#  'TuckerCarlson',
#  'JesseBWatters',
#  'WhiteHouse',
#  'Scavino45',
#  'KellyannePolls',
#  'Reince',
#  'RealRomaDowney',
#  'Trump',
#  'TrumpGolf',
#  'TiffanyATrump',
#  'IngrahamAngle',
#  'mike_pence',
#  'TeamTrump',
#  'DRUDGE_REPORT',
#  'MrsVanessaTrump',
#  'LaraLeaTrump',
#  'seanhannity',
#  'foxnation',
#  'CLewandowski_']

# %%
trump_friend_tweets = []
for friends in trump_friends:
    
    last_five = api.user_timeline(screen_name = friends,count=5)
    trump_friend_tweets.extend(last_five)

# %%
data = [[t.user.name, t.created_at, t.text] for t in trump_friend_tweets]

# %%
#as dictionary
data
# Out:
# [['Sarah Sanders',
#   datetime.datetime(2018, 2, 15, 13, 58, 21),
#   'RT @CBSThisMorning: NEW: President Trump orders U.S. flags to be flown at half-staff at all public buildings and grounds in honor of Parkla…'],
#  ['Sarah Sanders',
#   datetime.datetime(2018, 2, 15, 13, 54, 56),
#   'The President will address the nation at 11am today on the tragic shooting in Parkland, Florida'],
#  ['Sarah Sanders',
#   datetime.datetime(2018, 2, 14, 20, 53, 36),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Sarah Sanders',
#   datetime.datetime(2018, 2, 14, 13, 8, 16),
#   'The President’s policies are unleashing the American entrepreneurial spirit\n https://t.co/vUR7zu67Ds'],
#  ['Sarah Sanders',
#   datetime.datetime(2018, 2, 14, 13, 3, 30),
#   'RT @TheStalwart: A record number of U.S. small business owners say now is a good time to expand. \n\nIncredible chart. Just absolutely skyroc…'],
#  ['Tucker Carlson',
#   datetime.datetime(2018, 2, 14, 1, 58, 38),
#   "The Steele dossier is absurd. Take 10 minutes &amp; read it yourself. It's online. Ask yourself as you do: who would be… https://t.co/4Koh9gFPdt"],
#  ['Tucker Carlson',
#   datetime.datetime(2018, 2, 13, 1, 51, 17),
#   '#ICYMI part of my interview with a NOKO sympathizer https://t.co/VTNagSwIME'],
#  ['Tucker Carlson',
#   datetime.datetime(2018, 2, 13, 1, 19, 34),
#   "Progressives have a long history of supporting the World's most repressive regimes... It's hard to find a dictator… https://t.co/bO0EJ9ymCd"],
#  ['Tucker Carlson',
#   datetime.datetime(2018, 2, 10, 1, 28, 46),
#   "Here's what is clear right now, the bottom line on what we've learned this week and the one thing worth remembering… https://t.co/uJYc4SyRSh"],
#  ['Tucker Carlson',
#   datetime.datetime(2018, 2, 9, 2, 0, 18),
#   'Check out my interview with the real American heroes on their experience starring in the Clint Eastwood movie "The… https://t.co/VddBmwwHkG'],
#  ['Jesse Watters',
#   datetime.datetime(2018, 2, 14, 16, 44, 34),
#   'RT @TVNewsHQ: TV RATINGS: Fox News was the most-watched cable channel in daytime and prime time last week https://t.co/kUwtvxkMuO https://t…'],
#  ['Jesse Watters',
#   datetime.datetime(2018, 2, 14, 14, 58, 37),
#   "RT @FoxNews: .@JesseBWatters Rips Joy Behar: Dems 'OK With Rev. Wright Speaking to Obama' But Not Jesus Talking to Pence https://t.co/w2yxd…"],
#  ['Jesse Watters',
#   datetime.datetime(2018, 2, 14, 3, 35, 16),
#   "RT @FoxNewsInsider: .@JesseBWatters Rips @JoyVBehar: Dems 'OK With Rev. Wright Speaking to Obama' But Not Jesus Talking to @mike_pence, via…"],
#  ['Jesse Watters',
#   datetime.datetime(2018, 2, 14, 1, 46, 25),
#   'Catch me on @seanhannity tonight! https://t.co/Jx2sZjZUTk'],
#  ['Jesse Watters',
#   datetime.datetime(2018, 2, 14, 0, 13, 11),
#   "RT @FNC_Ladies_Rule: 📺@seanhannity 9pm ET @FoxNews \n\nIt's Tuesday so its  @JesseBWatters VS @JessicaTarlov https://t.co/6kFDeWMIjJ"],
#  ['The White House',
#   datetime.datetime(2018, 2, 15, 19, 26, 37),
#   'RT @realDonaldTrump: The Schumer-Rounds-Collins immigration bill would be a total catastrophe. @DHSgov says it would be “the end of immigra…'],
#  ['The White House',
#   datetime.datetime(2018, 2, 15, 18, 2, 28),
#   '"The Administration strongly opposes passage of the Schumer-Rounds-Collins Amendment." Statement from @PressSec reg… https://t.co/2t1fWFBPbA'],
#  ['The White House',
#   datetime.datetime(2018, 2, 15, 17, 34, 29),
#   'RT @realDonaldTrump: In times of tragedy, the bonds that sustain us are those of family, faith, community, and country. These bonds are str…'],
#  ['The White House',
#   datetime.datetime(2018, 2, 15, 16, 21, 29),
#   'President Trump delivers remarks on the tragedy in Parkland, FL: https://t.co/8RCpD3K8YX'],
#  ['The White House',
#   datetime.datetime(2018, 2, 15, 14, 58, 30),
#   'Presidential proclamation honoring the victims of the tragedy in Parkland, Florida: https://t.co/LR6VKFqcXJ'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 2, 15, 17, 37, 23),
#   'RT @realDonaldTrump: In times of tragedy, the bonds that sustain us are those of family, faith, community, and country. These bonds are str…'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 2, 14, 21, 8),
#   'RT @FLOTUS: My heart is heavy over the school shooting in Florida. Keeping all affected in my thoughts &amp; prayers.'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 2, 14, 20, 55, 44),
#   'RT @realDonaldTrump: Just spoke to Governor Rick Scott. We are working closely with law enforcement on the terrible Florida school shooting.'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 2, 14, 20, 55, 42),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 2, 14, 19, 13, 26),
#   'RT @realDonaldTrump: Today, I was honored to be joined by Republicans and Democrats from both the House and Senate, as well as members of m…'],
#  ['Kellyanne Conway',
#   datetime.datetime(2018, 2, 13, 23, 27, 48),
#   'RT @WhiteHouse: “We built the Empire State Building in just 1 year—is it not a disgrace that it can now take 10 years just to get a permit…'],
#  ['Kellyanne Conway',
#   datetime.datetime(2018, 2, 13, 23, 27, 22),
#   '2/2:\n\nTranscript, continued:\n\n-"There\'s a stigma &amp; a silence surrounding all of these issues"\n-"I hope those suffer… https://t.co/5EA6C4dEgV'],
#  ['Kellyanne Conway',
#   datetime.datetime(2018, 2, 13, 23, 19, 31),
#   '1/2: Many in media distorting what I said/how I feel. Transcript:\n-Tapper notes I\'ve "been outspoken on domestic vi… https://t.co/iaPBUm2DCR'],
#  ['Kellyanne Conway',
#   datetime.datetime(2018, 2, 13, 5, 18, 43),
#   '.@jaketapper: "strong women get abused...not just weak women"\n\nKellyanne: "many women get abused, no question, let… https://t.co/Ct86BsPNm0'],
#  ['Kellyanne Conway',
#   datetime.datetime(2018, 2, 9, 11, 19, 55),
#   'RT @EricTrump: Good job #GerberFoods! Such a beautiful boy!  Congratulations, Lucas! 👍🍼🇺🇸 https://t.co/ZhNPFLDjeW'],
#  ['Reince Priebus',
#   datetime.datetime(2018, 2, 10, 4, 38, 50),
#   'RT @hughhewitt: My interview w/ @Reince airs tomorrow at 8 AM EST on @MSNBC. The background on @realDonaldTrump decision making and staffin…'],
#  ['Reince Priebus',
#   datetime.datetime(2018, 2, 5, 4, 19, 9),
#   'RT @Favre4Official: So proud of my friend Doug Pederson and the performance his @Eagles showed tonight. Doug called a great game and his te…'],
#  ['Reince Priebus',
#   datetime.datetime(2018, 2, 2, 0, 48, 34),
#   'RT @MeetThePress: THIS SUNDAY: @Reince joins #MTP for an exclusive interview looking inside the Trump White House #IfitsSunday'],
#  ['Reince Priebus',
#   datetime.datetime(2018, 1, 31, 3, 36, 16),
#   'Absolutely incredible in every way.  That speech will be remembered and thought of as historically great.\n\nPOTUS crushed it tonight!'],
#  ['Reince Priebus',
#   datetime.datetime(2018, 1, 22, 17, 27, 5),
#   'Wow.  Dems miscalculated big league here.'],
#  ['Roma Downey',
#   datetime.datetime(2018, 2, 15, 16, 30, 43),
#   'A day in the life of Archie , our 200 lb Irish wolfhound ! ☘️ 🔆🔆🔆🔆🔆🔆🔆🔆🔆🔆 #irishwolfhound #dogs… https://t.co/7PKp9Tb5sE'],
#  ['Roma Downey',
#   datetime.datetime(2018, 2, 15, 14, 59, 33),
#   'Father in heaven please help us to deal with all the heartache in the world , all the violence… https://t.co/NkXG9UGAyR'],
#  ['Roma Downey',
#   datetime.datetime(2018, 2, 15, 7, 22, 17),
#   '@CaseysCreations Thanks'],
#  ['Roma Downey', datetime.datetime(2018, 2, 15, 7, 21, 57), '@hande_me ? 🦋'],
#  ['Roma Downey',
#   datetime.datetime(2018, 2, 15, 3, 10, 44),
#   '@shaunwhite Congrats 💛'],
#  ['The Trump Organization',
#   datetime.datetime(2018, 2, 14, 14, 59, 17),
#   'Happy #ValentinesDay from all of us at The @Trump Organization\u200b ❤️ https://t.co/di0syEzXE7'],
#  ['The Trump Organization',
#   datetime.datetime(2018, 2, 5, 21, 49, 31),
#   "Is your Valentine a @TrumpGolf fan? Show your love with a gift from our new Valentine's Collection:… https://t.co/me72kYR4d8"],
#  ['The Trump Organization',
#   datetime.datetime(2018, 1, 31, 22, 21, 43),
#   'Nearly 100 years later, the intricately designed vaults of #40WallStreet are still preserved in their original cond… https://t.co/vHF7ZHmYkT'],
#  ['The Trump Organization',
#   datetime.datetime(2018, 1, 30, 16, 50, 13),
#   'Dreaming of warmer days on the only course in Washington D.C., Maryland and Virginia with large scale Potomac River… https://t.co/N8RPy9tGLE'],
#  ['The Trump Organization',
#   datetime.datetime(2018, 1, 29, 23, 3, 41),
#   'Share your love with wine this #ValentinesDay 🍷 https://t.co/Ri7mV6fAsB https://t.co/mD05tbKVFD'],
#  ['Trump Golf',
#   datetime.datetime(2018, 2, 14, 15, 47),
#   'All for the love of golf #ValentinesDay @TrumpGolf ⛳ https://t.co/ATcbtTEF2i https://t.co/o8udv32oMQ'],
#  ['Trump Golf',
#   datetime.datetime(2018, 2, 5, 22, 5, 15),
#   'Of all the hazards, fear is the worst. ~ Sam Snead @TrumpGolfLA #MondayMotivation https://t.co/juQrJbVO78'],
#  ['Trump Golf',
#   datetime.datetime(2018, 2, 3, 19, 54, 40),
#   '@RickSmithGolf and @RoccoMediate back at @TrumpDoral where it all started with @RoccoMediate’s big @PGAtour win in… https://t.co/pnyGzrGw9J'],
#  ['Trump Golf',
#   datetime.datetime(2018, 1, 30, 17, 26, 40),
#   'A junior golf lesson involves much more than just hitting balls. Our programs teach them to play, compete, train, a… https://t.co/8CBw8hoOJS'],
#  ['Trump Golf',
#   datetime.datetime(2018, 1, 29, 21, 34, 27),
#   'Eternal summer @TrumpJupiter ☀️ https://t.co/soM6VmBlWa https://t.co/s0tiSIaivu'],
#  ['Tiffany Ariana Trump',
#   datetime.datetime(2018, 2, 8, 7, 29, 23),
#   '✨🎭 @ Lijst van bekende mensen uit Washington D.C. https://t.co/5OhmhkcF0R'],
#  ['Tiffany Ariana Trump',
#   datetime.datetime(2018, 1, 19, 5, 58, 42),
#   'My back to school 🎈📓 @ Georgetown Law https://t.co/kXHdn6qK9D'],
#  ['Tiffany Ariana Trump',
#   datetime.datetime(2017, 12, 27, 5, 41, 54),
#   'Wishing everyone a happy and peaceful year to come! 💕 @ Mar-a-Lago https://t.co/L447KMnzGn'],
#  ['Tiffany Ariana Trump',
#   datetime.datetime(2017, 12, 26, 20, 15, 26),
#   '❄️@IvankaTrump https://t.co/WQpczTkJfa'],
#  ['Tiffany Ariana Trump',
#   datetime.datetime(2017, 12, 26, 19, 59, 30),
#   '❄️ @ivankatrump https://t.co/Zu4QEoDnVX'],
#  ['Laura Ingraham',
#   datetime.datetime(2018, 2, 15, 16, 59, 18),
#   'Putin meets with the King of Jordan.  All smiles. https://t.co/tzQgzQaCAv'],
#  ['Laura Ingraham',
#   datetime.datetime(2018, 2, 15, 15, 34, 40),
#   "Can it really be the case that the @FBI Field Office in Mississippi not contact shooter's school(s) after seeing hi… https://t.co/d6yZVn98gx"],
#  ['Laura Ingraham',
#   datetime.datetime(2018, 2, 14, 21, 3, 39),
#   "The FBI, CIA and NSA say American citizens shouldn't use Huawei phones https://t.co/R2UvYvvnde via @CNNMoney"],
#  ['Laura Ingraham',
#   datetime.datetime(2018, 2, 14, 16, 27, 34),
#   'Happy Valentine’s Day!  Surprise someone special with something special—or just a call! #Love #KidsLove https://t.co/AWYkzQM87R'],
#  ['Laura Ingraham',
#   datetime.datetime(2018, 2, 14, 16, 26, 28),
#   'The FBI is right about one thing for sure — China is a severe threat to the US, and we need to protect and defend o… https://t.co/zLZ7dWhlmc'],
#  ['Mike Pence',
#   datetime.datetime(2018, 2, 2, 19, 6, 34),
#   "With @Saccone4PA18 in Congress, we're going to continue to keep our promises &amp; deliver on @realDonaldTrump's agenda… https://t.co/XV2Tw63MB8"],
#  ['Mike Pence',
#   datetime.datetime(2018, 2, 2, 18, 54, 30),
#   '.@Saccone4PA18 spent 10 yrs serving our country in uniform, protecting our freedom. When America went to war with I… https://t.co/3VYA4MKlJy'],
#  ['Mike Pence',
#   datetime.datetime(2018, 2, 2, 18, 50, 29),
#   "I'm here today to give the people of Pennsylvania a message from me &amp; @RealDonaldTrump: we need the Keystone State… https://t.co/RFADGnStus"],
#  ['Mike Pence',
#   datetime.datetime(2018, 2, 2, 16, 41, 7),
#   'Wheels up to Pennsylvania. People in SW PA need a congressman like @Saccone4PA18 to support President… https://t.co/LIeLhJjqyT'],
#  ['Mike Pence',
#   datetime.datetime(2017, 11, 16, 2, 15, 19),
#   "Great meeting w/ GOP Govs at @The_RGA on @realdonaldtrump's pro-JOBS tax cuts. Those Govs know all about tax cuts b… https://t.co/dtRW0yHr3S"],
#  ['Official Team Trump',
#   datetime.datetime(2018, 2, 15, 16, 33, 45),
#   'RT @WhiteHouse: President Trump delivers remarks on the tragedy in Parkland, FL: https://t.co/8RCpD3K8YX'],
#  ['Official Team Trump',
#   datetime.datetime(2018, 2, 14, 20, 52, 18),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Official Team Trump',
#   datetime.datetime(2018, 2, 14, 14, 10, 10),
#   'RT @GOP: Another 300 reasons to be happy @realDonaldTrump is President. #MAGA\nhttps://t.co/ZrJgzjvW7A'],
#  ['Official Team Trump',
#   datetime.datetime(2018, 2, 13, 20, 59, 2),
#   'RT @IvankaTrump: Infrastructure in the United States is crumbling and no longer meets the needs of the American public. +50K American bridg…'],
#  ['Official Team Trump',
#   datetime.datetime(2018, 2, 12, 22, 5, 30),
#   'Join President Trump in PENNSYLVANIA!\n\nRSVP TODAY: https://t.co/ksA3c1wiuU\n\n#MAGA #PA #Pennsylvania #Trump https://t.co/0Hi5eoW1pT'],
#  ['DRUDGE REPORT',
#   datetime.datetime(2018, 2, 15, 19, 53, 24),
#   'CRUZ THE WHITE SUPREMACIST https://t.co/D8Qoett2qS'],
#  ['DRUDGE REPORT',
#   datetime.datetime(2018, 2, 15, 19, 33, 21),
#   'SHACKLED AND COWERING https://t.co/ryNoJRJM5j'],
#  ['DRUDGE REPORT',
#   datetime.datetime(2018, 2, 15, 19, 28, 19),
#   "Claims 'Monica Lewinsky Dress'... https://t.co/mfg6xoCXQZ"],
#  ['DRUDGE REPORT',
#   datetime.datetime(2018, 2, 15, 19, 13, 12),
#   'Flu Vaccine Less Effective Than Earlier Estimates... https://t.co/90bDDD8uKF'],
#  ['DRUDGE REPORT',
#   datetime.datetime(2018, 2, 15, 19, 3, 9),
#   'MOM FLU DEATH SENT OVER EDGE? https://t.co/GMduAuOilQ'],
#  ['Vanessa Trump',
#   datetime.datetime(2018, 2, 13, 0, 26, 35),
#   'Thank you so much for all the help today in NYC! I appreciate all the quick response to make sure that I was safe !… https://t.co/50Az7BrkVi'],
#  ['Vanessa Trump',
#   datetime.datetime(2018, 1, 20, 14, 10, 54),
#   'RT @WhiteHouse: This is the behavior of obstructionist losers, not legislators. When Dems pay our armed forces &amp; first responders we will r…'],
#  ['Vanessa Trump',
#   datetime.datetime(2018, 1, 20, 14, 5, 51),
#   'RT @SpeakerRyan: The federal government is needlessly shut down this morning because of Senate Democrats. They need to stop this reckless g…'],
#  ['Vanessa Trump',
#   datetime.datetime(2018, 1, 20, 13, 27, 27),
#   'RT @VP: Honored to see troops based out of Peterson Air Force Base in Colorado while refueling in Ireland. They are headed to Kuwait for a…'],
#  ['Vanessa Trump',
#   datetime.datetime(2017, 11, 25, 23, 4, 14),
#   'I just finished decorating our tree with my kiddies ! We are in the holiday spirit! Christmas will be here soon ! https://t.co/xpmTBynWph'],
#  ['Lara Trump',
#   datetime.datetime(2018, 2, 15, 2, 39, 37),
#   '💘💘💘 #HappyValentinesDay https://t.co/j4JX4joRLF'],
#  ['Lara Trump',
#   datetime.datetime(2018, 2, 15, 2, 39, 2),
#   'RT @EricTrump: .@AlvedaCKing is truly an amazing person! @LaraLeaTrump and I have been so fortunate to have gotten to know her over the pas…'],
#  ['Lara Trump',
#   datetime.datetime(2018, 2, 15, 0, 51, 58),
#   'RT @dodo: Rescue pitties make the best service dogs 🌟 https://t.co/qrQIG6Lnb1'],
#  ['Lara Trump',
#   datetime.datetime(2018, 2, 8, 14, 26, 20),
#   'Happy day before Friday! 🇺🇸💙🇺🇸 https://t.co/fy7HYUHTUh'],
#  ['Lara Trump',
#   datetime.datetime(2018, 2, 7, 22, 30, 31),
#   'Porkchop is delicious and looking for a furever home! #AdoptDontShop https://t.co/HEvPXZAR5S'],
#  ['Sean Hannity',
#   datetime.datetime(2018, 2, 15, 19, 27, 29),
#   'Crisis in Korea https://t.co/f4tD4ORZz6'],
#  ['Sean Hannity',
#   datetime.datetime(2018, 2, 15, 18, 55, 43),
#   'RT @SaraCarterDC: LATEST: Mueller’s ‘Pit Bull’ Andrew Weissmann Busted for Withholding Evidence in Previous Case via @@SaraCarterDC https:/…'],
#  ['Sean Hannity',
#   datetime.datetime(2018, 2, 15, 17, 35, 13),
#   'Another smoking gun? https://t.co/aelFbg9QI9'],
#  ['Sean Hannity',
#   datetime.datetime(2018, 2, 15, 15, 43, 57),
#   'What we know so far, more info throughout the day and on radio and TV https://t.co/eSNSvjUbad'],
#  ['Sean Hannity',
#   datetime.datetime(2018, 2, 15, 1, 9, 17),
#   'Tonight on #Hannity at 9pm ET we will have the latest on today’s tragic shooting in Florida and hear from witnesses as well as experts'],
#  ['Fox Nation',
#   datetime.datetime(2018, 2, 14, 11, 21, 15),
#   ".@JesseBWatters Rips @JoyVBehar : @TheDemocrats 'OK With Rev. Wright Speaking to @BarackObama ' But Not Jesus Talki… https://t.co/kv14w3ywdQ"],
#  ['Fox Nation',
#   datetime.datetime(2018, 2, 14, 11, 16, 52),
#   '.@WSJopinion : John Kelly and the Chaos https://t.co/5esO6oJmJ0 #JohnKelly #RobPorter'],
#  ['Fox Nation',
#   datetime.datetime(2018, 2, 14, 11, 14, 51),
#   "RT @FoxNews: .@piersmorgan: 'Poisonous Viper' Omarosa Asked Me for Sex on 'Apprentice' to Try to 'Make Money' https://t.co/HlKHCqjWzS"],
#  ['Fox Nation',
#   datetime.datetime(2018, 2, 14, 11, 14, 37),
#   'RT @FoxNews: In swipe at #Trump, Berkeley becomes sanctuary city for marijuana https://t.co/3mYcbaXdc8'],
#  ['Fox Nation',
#   datetime.datetime(2018, 2, 14, 11, 14, 15),
#   'RT @campusreform: VIDEO: Students sign petition to ban ‘offensive’ Valentine’s Day https://t.co/IjWEy7U2Vr'],
#  ['Corey R. Lewandowski',
#   datetime.datetime(2018, 2, 14, 15, 40, 28),
#   'My latest op-ed in the Washington Times.  https://t.co/7XB0RT0ipP'],
#  ['Corey R. Lewandowski',
#   datetime.datetime(2018, 2, 12, 20, 47, 32),
#   'Budget will make our Military Great Again!  https://t.co/UVPCtWh6cB'],
#  ['Corey R. Lewandowski',
#   datetime.datetime(2018, 2, 12, 13, 22, 35),
#   'https://t.co/6uhnFHCNMM'],
#  ['Corey R. Lewandowski',
#   datetime.datetime(2018, 2, 11, 23, 16, 53),
#   'RT @JoeGruters: “Let Trump Be Trump” rally in Sarasota.   @CLewandowski_  &amp; @David_Bossie hit a home run today.  #MAGA @mattcaldwell_fl @Re…'],
#  ['Corey R. Lewandowski',
#   datetime.datetime(2018, 2, 10, 12, 24, 29),
#   'RT @FoxNews: .@CLewandowski_: “Democrats specifically put information in this memo that they knew the White House could not sign off on bec…'],
#  ['Ann Coulter',
#   datetime.datetime(2018, 2, 15, 19, 46, 14),
#   'RT @moshekasher: He makes a good point- everywhere religion flourishes, violence withers. https://t.co/sbkvI1c5ZF'],
#  ['Ann Coulter',
#   datetime.datetime(2018, 2, 15, 19, 45, 54),
#   'Are you going to stand for this BS attack, @realDonaldTrump?????\n https://t.co/uxMiyJSVgo'],
#  ['Ann Coulter',
#   datetime.datetime(2018, 2, 15, 19, 42, 55),
#   'RT @realDonaldTrump: The Schumer-Rounds-Collins immigration bill would be a total catastrophe. @DHSgov says it would be “the end of immigra…'],
#  ['Ann Coulter',
#   datetime.datetime(2018, 2, 15, 16, 50, 28),
#   'RT @MarieHyde: GA voters, those eight @gop members include our own @SenatorIsakson.\nCall 202-224-3121 tell him your opinion. https://t.co/I…'],
#  ['Ann Coulter',
#   datetime.datetime(2018, 2, 15, 16, 50, 16),
#   'In exchange for total amnesty/citizenship for illegals already here -- AND who come in the future - Senate immigrat… https://t.co/vsbGkAZlgF'],
#  ['Diamond and Silk®',
#   datetime.datetime(2018, 2, 15, 19, 16, 58),
#   'RT @realDonaldTrump: In times of tragedy, the bonds that sustain us are those of family, faith, community, and country. These bonds are str…'],
#  ['Diamond and Silk®',
#   datetime.datetime(2018, 2, 15, 16, 53, 45),
#   'Survivors of FL School Shooting Go On MSNBC, Blow the Left’s Narrative WIDE OPEN.\n\nhttps://t.co/9WIzfoPiFn'],
#  ['Diamond and Silk®',
#   datetime.datetime(2018, 2, 15, 14, 21, 41),
#   'Judge Serves Up NYC Bomber a Big Fat Slice of American Justice.\n\nLink:\xa0https://t.co/Q2xvKcikqK'],
#  ['Diamond and Silk®',
#   datetime.datetime(2018, 2, 15, 3, 6, 48),
#   'Our hearts go out to all in the wake of the Parkland Florida Tragedy.  You are in our thoughts and Prayers'],
#  ['Diamond and Silk®',
#   datetime.datetime(2018, 2, 15, 2, 36, 58),
#   'Looks like she put her foot in her mouth.....\n\nhttps://t.co/38II3kqwg0'],
#  ['KATRINA CAMPINS',
#   datetime.datetime(2018, 2, 15, 2, 35, 22),
#   'RT @IvankaTrump: Praying for the innocent lives lost, their families and the Parkland, Florida community in the wake of today’s unspeakable…'],
#  ['KATRINA CAMPINS',
#   datetime.datetime(2018, 2, 13, 17, 47, 2),
#   'Palm Beach $61,500,000\nFor more information contact me at KatrinaCampinsGroup@gmail.com\n\nThis… https://t.co/OdE1WDWFDP'],
#  ['KATRINA CAMPINS',
#   datetime.datetime(2018, 2, 9, 2, 56, 5),
#   'Palm Beach 🏝 Property Showings. https://t.co/tX4Yeb92Cj'],
#  ['KATRINA CAMPINS',
#   datetime.datetime(2018, 2, 5, 19, 52, 13),
#   'Just posted a photo @ Palm Beach, Florida https://t.co/lbOiO2mNjN'],
#  ['KATRINA CAMPINS',
#   datetime.datetime(2018, 2, 5, 19, 35, 27),
#   'pbpost @realdonaldtrump @erictrump #forsale #home #palmbeach #luxury #luxuryrealestate #trump @… https://t.co/8MGtupwowo'],
#  ['Katrina Pierson',
#   datetime.datetime(2018, 2, 14, 15, 1, 29),
#   'Had a wonderful #BlackHistoryMonth celebration @WhiteHouse w/ @POTUS &amp; @FLOTUS @realDonaldTrump @PARISDENNARD… https://t.co/mVKNDx3HQZ'],
#  ['Katrina Pierson',
#   datetime.datetime(2018, 2, 14, 14, 53, 12),
#   'RT @AmericaFirstPAC: .@USTreasury is making good on @realDonaldTrump\'s promise to slash regulations, "targeting nearly 300 IRS rules for th…'],
#  ['Katrina Pierson',
#   datetime.datetime(2018, 2, 14, 4, 3, 49),
#   'RT @realDonaldTrump: Our infrastructure plan has been put forward and has received great reviews by everyone except, of course, the Democra…'],
#  ['Katrina Pierson',
#   datetime.datetime(2018, 2, 14, 4, 3, 46),
#   'RT @realDonaldTrump: Negotiations on DACA have begun. Republicans want to make a deal and Democrats say they want to make a deal. Wouldn’t…'],
#  ['Katrina Pierson',
#   datetime.datetime(2018, 2, 14, 4, 3, 34),
#   'RT @AmericaFirstPAC: The future is bright for small business thanks to new management in Washington! S/O @realDonaldTrump \nhttps://t.co/oQq…'],
#  ['Michael Cohen',
#   datetime.datetime(2018, 2, 14, 21, 35, 50),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Michael Cohen',
#   datetime.datetime(2018, 2, 13, 13, 49, 15),
#   '@realDonaldTrump The #Dreamers deserve a decision instead of waiting and waiting and waiting with uncertainty.'],
#  ['Michael Cohen',
#   datetime.datetime(2018, 2, 13, 13, 47, 57),
#   'RT @realDonaldTrump: Negotiations on DACA have begun. Republicans want to make a deal and Democrats say they want to make a deal. Wouldn’t…'],
#  ['Michael Cohen',
#   datetime.datetime(2018, 2, 13, 12, 26, 12),
#   '@FoxNews @JesseBWatters @POTUS .yes he has and yes he will! #RebuildingAmerica'],
#  ['Michael Cohen',
#   datetime.datetime(2018, 2, 13, 12, 25, 48),
#   'RT @FoxNews: .@JesseBWatters: "I do like the infrastructure package. I think @POTUS has been known to get projects done on time &amp; under bud…'],
#  ['FOX & friends',
#   datetime.datetime(2018, 2, 15, 19, 35, 3),
#   '"In these moments of heartache...we hold onto God\'s word in scripture -- \'I have heard your prayer and seen your te… https://t.co/d6R6CNyRrz'],
#  ['FOX & friends',
#   datetime.datetime(2018, 2, 15, 19, 5, 42),
#   '.@SenTedCruz: Sadly, this evil could happen anywhere – but we have to work to try to prevent it https://t.co/PDhWThE9KH'],
#  ['FOX & friends',
#   datetime.datetime(2018, 2, 15, 17, 0, 6),
#   '.@marcorubio: To be frank, I’m not sure any of the four immigration plans have the votes to pass today https://t.co/beHxT8g8F4'],
#  ['FOX & friends',
#   datetime.datetime(2018, 2, 15, 16, 49, 36),
#   'RT @kilmeade: Investigators frantically search for answers after the horrific school shooting in Parkland, FL - Florida @SenBillNelson join…'],
#  ['FOX & friends',
#   datetime.datetime(2018, 2, 15, 16, 45, 1),
#   '.@marcorubio: The full picture of this person shows a potentially serious problem. What can we do to get ahead of i… https://t.co/mKQ2DLd62O'],
#  ['MELANIA TRUMP',
#   datetime.datetime(2018, 1, 20, 19, 42, 15),
#   'RT @FLOTUS: This has been a year filled with many wonderful moments. I’ve enjoyed the people I’ve been lucky enough to meet throughout our…'],
#  ['MELANIA TRUMP',
#   datetime.datetime(2018, 1, 20, 19, 42, 11),
#   'RT @FLOTUS: Today we honor Dr. Martin Luther King Jr. &amp; his service to this great country.  I am honored to be First Lady of a nation that…'],
#  ['MELANIA TRUMP',
#   datetime.datetime(2018, 1, 20, 19, 42, 7),
#   'RT @FLOTUS: It was a productive week with meetings, meetings &amp; more meetings!  Lots of work to be done in 2018 - looking forward to the yea…'],
#  ['MELANIA TRUMP',
#   datetime.datetime(2018, 1, 20, 19, 42, 2),
#   'RT @FLOTUS: Wishing everyone a Joyous, Healthy and Prosperous #NewYear2018! ✨'],
#  ['MELANIA TRUMP',
#   datetime.datetime(2018, 1, 20, 19, 41, 59),
#   'RT @realDonaldTrump: MERRY CHRISTMAS!!! https://t.co/mYtV5GNdLl'],
#  ['Geraldo Rivera',
#   datetime.datetime(2018, 2, 15, 19, 39, 12),
#   'How many #AR15 type military-style assault weapons are in circulation in the USA? It is certainly a number deep in… https://t.co/3aBLrgZdue'],
#  ['Geraldo Rivera',
#   datetime.datetime(2018, 2, 15, 19, 12, 42),
#   'Too many missed clues in #ParklandSchoolShooting #NikolasCruz was shouting out his intention to commit murder &amp; may… https://t.co/U6NqHQRRzE'],
#  ['Geraldo Rivera',
#   datetime.datetime(2018, 2, 15, 12, 33, 59),
#   'Like manufacturers of #Oxycodone Manufacturers of #AR-15 should be held liable when their products-military-style a… https://t.co/s95E84TXT8'],
#  ['Geraldo Rivera',
#   datetime.datetime(2018, 2, 14, 21, 23, 27),
#   '@BillWeirCNN They called Mao plenty of insults a lot worse than rocket man, and vice versa. Times change'],
#  ['Geraldo Rivera',
#   datetime.datetime(2018, 2, 14, 21, 20, 36),
#   'They caught the little shit in #FloridaShooting Schools are too vulnerable. A straight line can be drawn from 1999… https://t.co/E49yd9YsLi'],
#  ['Eric Bolling',
#   datetime.datetime(2018, 2, 15, 17, 44, 34),
#   'Aaron Feis:\nCoach\nEducator\nProtector\n🇺🇸HERO🇺🇸\n\nhttps://t.co/vcPpQX1w9y'],
#  ['Eric Bolling',
#   datetime.datetime(2018, 2, 14, 20, 52, 56),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Eric Bolling',
#   datetime.datetime(2018, 2, 14, 15, 9, 53),
#   'If you’re worried about a loved one using or abusing opioids, take a few minutes and watch this. I hope it inspires… https://t.co/gLeaKtF6eF'],
#  ['Eric Bolling',
#   datetime.datetime(2018, 2, 14, 14, 54, 47),
#   'Thank you for having me on @Morning_Joe this morning talking about the #OpioidEpidemic   @JoeNBC @morningmika https://t.co/ge9HwE6cNt'],
#  ['Eric Bolling',
#   datetime.datetime(2018, 2, 14, 13, 8, 11),
#   'Good morning friends!!\n\nHeading over to @MSNBC now @Morning_Joe to talk #opioidcrisis. Then off to the White House… https://t.co/8th2wo2QGR'],
#  ['Mark Burnett',
#   datetime.datetime(2018, 1, 4, 23, 28, 27),
#   'Absolutely loved @JeffProbst’s inspirational interview on @LightWorkers where he discusses the importance of commun… https://t.co/Ss82VHp3qT'],
#  ['Mark Burnett',
#   datetime.datetime(2017, 11, 16, 2, 21, 45),
#   'RT @JeffProbst: Survivor is on!   Fun ep tonight and a crazy spaghetti reward!!'],
#  ['Mark Burnett',
#   datetime.datetime(2017, 10, 10, 0, 37, 6),
#   'RT @NBCTheVoice: This is it! RETWEET because the final week of #VoiceBlinds start NOW on @nbc. https://t.co/UJ4KvzRosp'],
#  ['Mark Burnett',
#   datetime.datetime(2017, 9, 28, 17, 47, 50),
#   'RT @ABCSharkTank: Sink your teeth into an all-new season of #SharkTank. Starts Sunday with a two-hour premiere at 8|7c on ABC! https://t.co…'],
#  ['Mark Burnett',
#   datetime.datetime(2017, 9, 27, 21, 2, 50),
#   "RT @survivorcbs: Get ready to get sucked back in. Don't miss the #Survivor Season 35 premiere tonight at 8/7c on CBS: https://t.co/mjTq8NUC…"],
#  ['Gary Player',
#   datetime.datetime(2018, 2, 15, 19, 29, 19),
#   'RT @USGA: In 1972, @garyplayer brought Lee Elder to South Africa amidst apartheid, and inspired a nation. #BlackHistoryMonth https://t.co/T…'],
#  ['Gary Player',
#   datetime.datetime(2018, 2, 15, 18, 45, 53),
#   'RT @BelgianGolfer: The par 5 2nd hole at Modry Las Golf Resort in Poland. Gary Player design from 2009 and one of the best in the country.…'],
#  ['Gary Player',
#   datetime.datetime(2018, 2, 15, 18, 44, 6),
#   'RT @BlackKnightIntl: When you realize that The Masters is in 50 days https://t.co/Qu4U4bGs5i'],
#  ['Gary Player',
#   datetime.datetime(2018, 2, 15, 1, 15, 11),
#   'RT @ChampionsLeague: Nothing but respect between Cristiano Ronaldo and Neymar. 👏 #UCL https://t.co/kntH9tBFGQ'],
#  ['Gary Player',
#   datetime.datetime(2018, 2, 14, 21, 42, 14),
#   'RT @ClevelandClinic: Could retirement actually be bad for your health? https://t.co/hJIsJvDUjz'],
#  ['Vince McMahon',
#   datetime.datetime(2018, 2, 10, 17, 0, 22),
#   "If there's anyone that can chaperone a high school dance, it's @JohnCena. https://t.co/rnb8a4YFyu"],
#  ['Vince McMahon',
#   datetime.datetime(2018, 2, 9, 23, 34, 29),
#   'I love this. https://t.co/y7TBCzv7FW'],
#  ['Vince McMahon',
#   datetime.datetime(2018, 2, 9, 20, 42, 17),
#   'RT @TitusONeilWWE: TIME For Me and @JoeBiden to hit the @AFLV #AFLVCentral Stages to Educate,Inspire and Engage with the over 3600 Student…'],
#  ['Vince McMahon',
#   datetime.datetime(2018, 2, 9, 20, 2, 54),
#   'RT @StephMcMahon: One of the key lessons I’ve learned from @VinceMcMahon is to never be afraid to take calculated risks. https://t.co/H07qp…'],
#  ['Vince McMahon',
#   datetime.datetime(2018, 2, 2, 20, 0, 14),
#   'Andre the Giant was an extraordinary human being who lived an extraordinary life. https://t.co/tBAwhXqep3'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 1, 18, 17, 11, 47),
#   'Two great President’s enjoying their burgers &amp; fries! #ThrowbackThursday https://t.co/HW4RCzkqLT'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 1, 12, 3, 25, 11),
#   '2016 Michigan #ThrowbackThursday w/candidate @realDonaldTrump! \n\nJanuary 11, 2018\nFiat Chrysler to invest more than… https://t.co/pRK2ARHJXq'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 1, 11, 3, 48, 15),
#   'Check out the FRAUD, Michael Wolff! #WolffTheFraud https://t.co/b8Xpiu0L7w'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 1, 4, 2, 42, 43),
#   'Seems like I took this photo yesterday of @SpeakerBoehner &amp; NYC Businessman @realDonaldTrump, out for a round of go… https://t.co/Ea8nugKix5'],
#  ['Dan Scavino Jr.',
#   datetime.datetime(2018, 1, 2, 2, 1, 36),
#   '#RoseBowl🌹#CFBPlayoff\n\nTIED UP AT 45! What a great game! \n\nReminds me of our GREAT 45th POTUS - who is MAKING AMERI… https://t.co/4VkB6tIKtX'],
#  ['Trump National Doral',
#   datetime.datetime(2018, 2, 14, 18, 50, 8),
#   "We think it's no coincidence that #ValentinesDay landed on a #WeddingWednesday this year. To celebrate, we're shari… https://t.co/hViaDyGeMB"],
#  ['Trump National Doral',
#   datetime.datetime(2018, 2, 13, 19, 6, 4),
#   'RT @VISITFLORIDA: Thanks to all who attended &amp; contributed to #FLTravelChat today. Our next chat will be on March 13, 2018. Save the date!…'],
#  ['Trump National Doral',
#   datetime.datetime(2018, 2, 13, 19, 4, 15),
#   '@heatherslg Here, let us give you a closer look... #FLTravelChat https://t.co/FxvWitw86B'],
#  ['Trump National Doral',
#   datetime.datetime(2018, 2, 13, 18, 56, 4),
#   "A8:  The one, can't miss thing for families to do in Florida? Soak up the Florida sunshine! #FLTravelChat #LoveFL https://t.co/iChjhOSctl"],
#  ['Trump National Doral',
#   datetime.datetime(2018, 2, 13, 18, 49, 10),
#   "A7:  For our guests, it's a tie between our championship golf courses and our 48,000 square foot spa. Which would y… https://t.co/JmGTl4jnnf"],
#  ['Trump Charlotte',
#   datetime.datetime(2018, 2, 12, 16, 24, 28),
#   "Valentine's Day is just around the corner, you can call ahead for special orders or simply stop by Trump Bakery to… https://t.co/WgPvKxHac8"],
#  ['Trump Charlotte',
#   datetime.datetime(2018, 2, 4, 22, 45, 23),
#   'Ready for Super Bowl 52! 🏈\nWhich do you like more, the game or the commercials? Either way our team has prepared an… https://t.co/2Wdfq649dm'],
#  ['Trump Charlotte',
#   datetime.datetime(2018, 2, 3, 21, 9, 12),
#   "RT @TrumpStore: Show your love with a gift from our new Valentine's Collection. Shop now: https://t.co/sqhTzLY4kR … #ValentinesDay #Valenti…"],
#  ['Trump Charlotte',
#   datetime.datetime(2018, 2, 1, 17, 27, 8),
#   "RT @Cardiogolf1: It's Back-The Cardiogolf 1000 Practice Swing Challenge! The challenge is straightforward-simply make 1000 practice swings…"],
#  ['Trump Charlotte',
#   datetime.datetime(2018, 1, 27, 13, 54, 19),
#   'Bow Ties and Chocolate Cake = The Ultimate Cool!\n#NationalChocolateCakeDay https://t.co/41NRyu3ew0'],
#  ['Trump Vegas Hotel',
#   datetime.datetime(2017, 8, 8, 20, 27, 20),
#   'Roasted #salmon with chorizo &amp; navy bean fricassee, string potatoes, and confit lemon puree. #DJTKitchen… https://t.co/NCl2AF2ryS'],
#  ['Trump Vegas Hotel',
#   datetime.datetime(2017, 8, 5, 16, 25, 5),
#   'Stay in cozy comfort a few minutes longer - treat yourself to #BreakfastInBed. #Indulge #LuxuryTravel #VegasTravel https://t.co/hAF0YmE4HS'],
#  ['Trump Vegas Hotel',
#   datetime.datetime(2017, 8, 4, 22, 2, 11),
#   'Our chefs at #DJTKitchen prepare your dish with the finest microgreens, locally sourced from Herbs by Diane.… https://t.co/ihJA7MRnTz'],
#  ['Trump Vegas Hotel',
#   datetime.datetime(2017, 8, 2, 18, 33, 50),
#   'May we have the pleasure of serving you? #PoolsideLuxury #PoolDay #Luxury #YouDeserveIt #Poolside https://t.co/g3FyOGGU7e'],
#  ['Trump Vegas Hotel',
#   datetime.datetime(2017, 7, 29, 16, 25, 5),
#   'Be pampered with lavish care &amp; enjoy all the comforts of home – including a kitchen in every room. #Kitchenette… https://t.co/XK6b7mSH9x'],
#  ['Trump Hotel Chicago',
#   datetime.datetime(2018, 1, 31, 2, 13, 28),
#   'Just less than 16 hours left on our $208 Anniversary Rate Sale! \nhttps://t.co/4DP0z8KSo7 \n\n#TrumpChi10 #trump https://t.co/LC62qlfQAT'],
#  ['Trump Hotel Chicago',
#   datetime.datetime(2018, 1, 30, 17, 28, 13),
#   '10 yrs. ago today, we opened at approx. 12pm &amp; welcomed the 1st of many guests to the hotel. Thank U for 10 amazing… https://t.co/IRH8VpgpWh'],
#  ['Trump Hotel Chicago',
#   datetime.datetime(2018, 1, 9, 22, 50, 23),
#   'RT @TrumpHotels: Soaring 92 stories (1,388 ft), @TrumpChicago is one of the tallest reinforced concrete buildings in the world https://t.co…'],
#  ['Trump Hotel Chicago',
#   datetime.datetime(2017, 12, 28, 15, 33, 30),
#   '#TBT https://t.co/WJXXLopLyX'],
#  ['Trump Hotel Chicago',
#   datetime.datetime(2017, 12, 27, 17, 44, 36),
#   "RT @philvettel: Save the Tables: Last-minute New Year's Eve reservations at 178 Chicago restaurants https://t.co/XR3HuN3jbB"],
#  ['Trump Washington DC',
#   datetime.datetime(2018, 2, 11, 14, 7, 11),
#   'Thank you to all of our Members that joined us for our Father-Daughter Dance!'],
#  ['Trump Washington DC',
#   datetime.datetime(2018, 2, 8, 16, 59, 44),
#   "Table numbers |  If you look closely, you'll see that the tables were not numbered in numerical order as one... https://t.co/q0CaZK1DqR"],
#  ['Trump Washington DC',
#   datetime.datetime(2018, 2, 8, 16, 8, 57),
#   "Table numbers |  If you look closely, you'll see that the tables were not numbered in numerical… https://t.co/j1Awo1D0yz"],
#  ['Trump Washington DC',
#   datetime.datetime(2018, 2, 6, 14, 41, 23),
#   'Trump National DC  |  Photo by Rich Kessler @ Trump National Golf Club Washington D.C. https://t.co/hpbLkpE1dC'],
#  ['Trump Washington DC',
#   datetime.datetime(2018, 2, 2, 15, 17, 18),
#   'Thank you to all of our Members who joined our Paint and Sip event last night!'],
#  ['Trump Los Angeles',
#   datetime.datetime(2018, 2, 14, 4, 16, 58),
#   'RT @RickSmithGolf: Great trip so far this week to Los Angeles! Spent some time @pgatour @genesisopen and checked out new Golf Academy site…'],
#  ['Trump Los Angeles',
#   datetime.datetime(2018, 2, 13, 22, 50, 31),
#   '45,000 square foot Clubhouse which includes; event spaces, restaurants, locker rooms, with more and an award winnin… https://t.co/Um0VgLxDa7'],
#  ['Trump Los Angeles',
#   datetime.datetime(2018, 2, 10, 0, 14, 9),
#   'Indulge yourself in #FoodieFriday, come and enjoy our Pan Seared Diver Scallops! #TrumpNationalLA #FoodieFriday #LA… https://t.co/mWyWBa43U1'],
#  ['Trump Los Angeles',
#   datetime.datetime(2018, 2, 7, 18, 55, 38),
#   'Thank you to @_erlewine_ for this amazing shot! #TrumpNationalLA #GolfCourse #Sunset #Beautiful https://t.co/kFePq1HcFM'],
#  ['Trump Los Angeles',
#   datetime.datetime(2018, 1, 31, 17, 39, 27),
#   'Come join us for another fun filled Super Bowl Sunday at Trump National LA! #SuperSunday #SuperBowlSunday #2018… https://t.co/4g5uyOl4i5'],
#  ['Eric Trump',
#   datetime.datetime(2018, 2, 15, 12, 41, 13),
#   'Trump National D.C. @TrumpGolfDC #PotomacRiver https://t.co/98y8dmaA36'],
#  ['Eric Trump',
#   datetime.datetime(2018, 2, 15, 12, 34, 30),
#   'RT @Trump: Nearly 100 years later, the intricately designed vaults of #40WallStreet are still preserved in their original condition #TheTru…'],
#  ['Eric Trump',
#   datetime.datetime(2018, 2, 14, 21, 1, 35),
#   'RT @realDonaldTrump: My prayers and condolences to the families of the victims of the terrible Florida shooting. No child, teacher or anyon…'],
#  ['Eric Trump',
#   datetime.datetime(2018, 2, 14, 20, 44, 54),
#   '.@AlvedaCKing is truly an amazing person! @LaraLeaTrump and I have been so fortunate to have gotten to know her ove… https://t.co/HvJ6Ydoxfx'],
#  ['Eric Trump',
#   datetime.datetime(2018, 2, 14, 12, 45, 34),
#   'Happy #ValentinesDay to my great wife @LaraLeaTrump. Thank you for #BabyLuke and our amazing family. I love you ver… https://t.co/aRyVb5tffW'],
#  ["Bill O'Reilly",
#   datetime.datetime(2018, 2, 15, 16, 55, 4),
#   'Tonight on https://t.co/fqUvO5EEW0, we will not waste your time. We’ll provide some specific things that can be don… https://t.co/0VPB4B76PN'],
#  ["Bill O'Reilly",
#   datetime.datetime(2018, 2, 15, 16, 54, 25),
#   'Can’t take it anymore. All morning I have wasted my time listening to cable news “analysts” fail to provide any wor… https://t.co/AMFBBSY9ng'],
#  ["Bill O'Reilly",
#   datetime.datetime(2018, 2, 15, 15, 36, 3),
#   'https://t.co/FY6DXUU9x6'],
#  ["Bill O'Reilly",
#   datetime.datetime(2018, 2, 15, 15, 30, 24),
#   "It is all about rage when kids decide to kill. Money is not involved nor is political terror. It's personal. https://t.co/QpV4v5DuBf"],
#  ["Bill O'Reilly",
#   datetime.datetime(2018, 2, 15, 15, 29, 20),
#   'The epidemic of school shootings is obviously a very troubling part of American life. Although violent crime is dow… https://t.co/wBAmCbL6jN'],
#  ['Greta Van Susteren',
#   datetime.datetime(2018, 2, 15, 19, 55, 39),
#   'RT @VOANews: Former Presidential Candidate Ordered Detained for Two Weeks in Egypt\xa0 https://t.co/98IL2PIV0U https://t.co/jUQ88cUPmA'],
#  ['Greta Van Susteren',
#   datetime.datetime(2018, 2, 15, 19, 53, 55),
#   'RT @W7VOA: Passengers reporting evacuation of Union Station in Washington, DC. https://t.co/w87lqEJGZC'],
#  ['Greta Van Susteren',
#   datetime.datetime(2018, 2, 15, 19, 50, 44),
#   'Wish US media would report more on Sudan https://t.co/1x05QvkQ0G'],
#  ['Greta Van Susteren',
#   datetime.datetime(2018, 2, 15, 19, 49, 51),
#   'The world has looked the other way as Pres #Bashir travels the world while under indictment for genocide at #ICC https://t.co/sLToRjsJAV'],
#  ['Greta Van Susteren',
#   datetime.datetime(2018, 2, 15, 17, 59, 24),
#   'I like @ChrisCuomo - you may not agree with him but why insult him ? Why not just lay out your different opinions a… https://t.co/ARBQWlf9Bo'],
#  ['Piers Morgan',
#   datetime.datetime(2018, 2, 15, 19, 42, 34),
#   'Oh I know, we’re such spoilsports aren’t we? https://t.co/YHtwrBD8p8'],
#  ['Piers Morgan',
#   datetime.datetime(2018, 2, 15, 19, 29, 7),
#   'Strong presidents prioritise &amp; do deals to get their priorities done. Obama was too busy deporting 3m people, dropp… https://t.co/4DpNMcaDBe'],
#  ['Piers Morgan',
#   datetime.datetime(2018, 2, 15, 19, 13, 44),
#   '*VIDEO*\nI fired an AR-15 during a guns show special for CNN.\nIt was terrifying how easy &amp; fast they are to use:\nhttps://t.co/Ho12fIytId'],
#  ['Piers Morgan',
#   datetime.datetime(2018, 2, 15, 19, 7, 39),
#   'RT @GMB: In light of the Florida school massacre, here’s @piersmorgan interviewing @realDonaldTrump about gun violence in the US. https://t…'],
#  ['Piers Morgan',
#   datetime.datetime(2018, 2, 15, 18, 57, 27),
#   'Yes, well in Britain we decided to bully politicians into changing gun laws - you spineless twerps should try it so… https://t.co/gq5hqpWNHy'],
#  ['Donald Trump Jr.',
#   datetime.datetime(2018, 2, 15, 17, 47, 3),
#   'Why The Media Stopped Reporting The Russia Collusion Story https://t.co/OxCGs1kILG'],
#  ['Donald Trump Jr.',
#   datetime.datetime(2018, 2, 15, 12, 39, 24),
#   'Wonder why he would do that? It’s almost as though he realizes that the conflict is terrible... but hey his wife co… https://t.co/sprO4N9ZXP'],
#  ['Donald Trump Jr.',
#   datetime.datetime(2018, 2, 15, 12, 27),
#   'RT @MZHemingway: EXCLUSIVE: DOJ Official Bruce Ohr Hid Wife’s Fusion GPS Payments From Ethics Officials https://t.co/g0hqFKeomZ'],
#  ['Donald Trump Jr.',
#   datetime.datetime(2018, 2, 15, 2, 40, 37),
#   "RT @SecretsBedard: Pushback: Cops, FBI, Border agents, 'absolutely enthralled' with @realDonaldTrump, reject claim his criticism of FBI bra…"],
#  ['Donald Trump Jr.',
#   datetime.datetime(2018, 2, 15, 0, 40, 40),
#   'RT @DonaldJTrumpJr: Great article! This has been my experience across the board. Law enforcement fully supports @realDonaldTrump &amp; he fully…'],
#  ['Ivanka Trump',
#   datetime.datetime(2018, 2, 15, 1, 33, 16),
#   'Praying for the innocent lives lost, their families and the Parkland, Florida community in the wake of today’s unspeakable tragedy.'],
#  ['Ivanka Trump',
#   datetime.datetime(2018, 2, 14, 16, 26, 38),
#   "RT @RhianNAEYC: .@IvankaTrump, we are excited about last week's bipartisan #BudgetDeal, signed by the President, which will #DoubleCCDBG &amp;…"],
#  ['Ivanka Trump',
#   datetime.datetime(2018, 2, 13, 20, 44, 42),
#   'Record Number of U.S. Small-Business Owners Say It’s a Good Time to Expand  https://t.co/uHce0mHPhV'],
#  ['Ivanka Trump',
#   datetime.datetime(2018, 2, 13, 20, 32, 45),
#   'Infrastructure in the United States is crumbling and no longer meets the needs of the American public. +50K America… https://t.co/KO81M9Lhl3'],
#  ['Ivanka Trump',
#   datetime.datetime(2018, 2, 13, 18, 46, 59),
#   'An incredible day in Pittsburgh, PA discussing #TaxReform and #Deregulation with small business owners and local of… https://t.co/qmHvM78eex']]

# %%
import pandas as pd

labels = ['username', 'date', 'text']
df = pd.DataFrame.from_records(data, columns=labels)
df = df.sort_values(by='date',ascending=False)


df.head()
# Out:
#                   username                date  \
# 40  The Trump Organization 2018-02-15 20:25:48
# 70           DRUDGE REPORT 2018-02-15 20:24:51
# 20         Dan Scavino Jr. 2018-02-15 20:19:50
# 85            Sean Hannity 2018-02-15 20:18:17
# 71           DRUDGE REPORT 2018-02-15 20:14:46
#
#                                                  text
# 40  Can't leave home without your furry friend? Wi...
# 70  TRUMP ADDRESSES GRIEVING NATION... https://t.c...
# 20  RT @realDonaldTrump: Presidential Proclamation...
# 85  WATCH: FBI Agent comments on claims the bureau...
# 71  Snowboarder breaks neck in terrifying crash......

# %%
df
# Out:
#                   username                date  \
# 40  The Trump Organization 2018-02-15 20:25:48
# 70           DRUDGE REPORT 2018-02-15 20:24:51
# 20         Dan Scavino Jr. 2018-02-15 20:19:50
# 85            Sean Hannity 2018-02-15 20:18:17
